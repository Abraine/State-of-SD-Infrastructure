# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re 
import difflib

# %%
col_name = ["COLLISION_DATE","COLLISION_TIME","PRIMARY_RD","SECONDARY_RD","CHP_BEAT_TYPE","WEATHER_1","COLLISION_SEVERITY","PRIMARY_COLL_FACTOR","PCF_VIOL_CATEGORY","LIGHTING","ROAD_SURFACE","ROAD_COND_1"]
MVA_DF = pd.DataFrame(data=None, index=None, columns=col_name, dtype=None) #New empty dataframe
size=0
for i in range (1):
    year = 2015 #File name
    DF = pd.read_csv('CollisionRecords_%i.csv' % year,sep = '\t', dtype='unicode') #Read the csv file
    DF = DF[col_name]
    size += len(DF) #Check size matches 
    MVA_DF = MVA_DF.append(DF)#Add DF to our initialized dataframe

     
#Just to check
print(size)#Just to check
# Out:
# 10075

# %%
year = 2011 #Only OCI file that I have 
DF_OCI = pd.read_csv('OCI_SD_%i.csv' % year,sep = ',', dtype='unicode') #Read the csv file
DF_OCI= DF_OCI[['oci','street','street_from','street_to','oci_desc']] #Keep only relevant variables
DF_OCI
# Out:
#          oci                   street          street_from  \
# 0      49.23                  TEBO CT           PICADOR BL
# 1      35.32                  04TH AV                 K ST
# 2      78.48             MELBOURNE DR             SHAWN AV
# 3      34.29                BAYARD ST              REED AV
# 4      28.28                QUINCE DR              06TH AV
# 5      75.72              PRINCESS ST         SPINDRIFT DR
# 6      83.43             CLAVELITA ST            ARLISS CT
# 7        100                  IRIS AV            ALBATA CT
# 8      51.55                ARLISS CT         CLAVELITA ST
# 9      45.26                     K ST              19TH ST
# 10     28.94                     K ST              22ND ST
# 11     78.95           MEADOWBROOK DR          GLOAMING AV
# 12     13.47                  36TH ST                 K ST
# 13     61.06           SAN VICENTE ST       SAN VICENTE WY
# 14        39               MADRONE AV           RITCHEY ST
# 15        57                  TICO CT            DARWIN WY
# 16     69.95               REDWOOD ST              60TH ST
# 17     47.29                  19TH ST                 E ST
# 18     38.02                   GUY ST             COUTS ST
# 19        51               POBLADO RD         MOON SONG CT
# 20     74.31               W LEWIS ST             EAGLE ST
# 21       100           STONEBRIDGE PY         MERRITAGE CT
# 22      83.4           ROSE GARDEN CT       STONEBRIDGE PY
# 23     76.77             MERRITAGE CT       STONEBRIDGE PY
# 24      69.8          AVALON VISTA CT                BEGIN
# 25     75.59            TIMBERGATE CR   CHICARITA CREEK RD
# 26     81.13             HALF MILE DR        HIGH BLUFF DR
# 27     55.12               DE MAYO RD                BEGIN
# 28     75.95               CICHLID WY          DARKWOOD RD
# 29      47.4               SALINAS WY           TRIPOLI RD
# ...      ...                      ...                  ...
# 28068  77.18             BEDFORD HILL     CONCORD RIDGE TR
# 28069    100              CAM DEL SUR       BING CROSBY BL
# 28070  67.19       DEL MAR HEIGHTS RD          SEAGROVE ST
# 28071  67.45              JUDICIAL DR      GOLDEN HAVEN DR
# 28072     56               DRUCKER LN             KERNS ST
# 28073  47.54             ZASLAVSKY PL         NIGHTHAWK LN
# 28074  83.61          SIEMPRE VIVA CT    BRITANNIA PARK PL
# 28075  81.44              LARKDALE AV            MACAWA AV
# 28076  87.84              LARKDALE AV             KRENZ ST
# 28077    100              CAM DEL SUR          FOUR GEE RD
# 28078  54.69            SUTHERLAND ST     PACIFIC (FTG) HY
# 28079  35.36              SANDROCK RD          GRAMERCY DR
# 28080  42.56                MACAWA AV             AFTON RD
# 28081  63.89                  NEVA AV          LARKDALE AV
# 28082  84.34     PACIFIC HIGHLANDS PY     CARMEL VALLEY RD
# 28083   63.9        RANCHO DEL SOL WY     MORNING GLORY WY
# 28084  84.34               DECATUR RD            SOMERS LN
# 28085   82.9              FARRAGUT RD                BEGIN
# 28086  77.94                  SIMS RD  HISTORIC DECATUR RD
# 28087     69       BRIARLAKE WOODS DR       HEATHER RUN CT
# 28088  31.46                 LOGAN AV            S 43RD ST
# 28089  76.89                S 43RD ST             LOGAN AV
# 28090  59.89                ARDATH RD     HIDDEN VALLEY RD
# 28091  86.03            TOYON MESA CT      RANCHO TOYON PL
# 28092  79.29          CALLE CRISTOBAL         CAM SANTA FE
# 28093  61.71  RANCHO SANTA FE FARM RD       CAMTO MENDIOLA
# 28094  80.57              CHAUNCEY ST           CUSHING RD
# 28095    100             OLD CREEK RD          CAROWIND LN
# 28096  79.33          GREEN VALLEY CT                BEGIN
# 28097  79.02          VIA SANTA BRISA  WHISPERING RIDGE RD
#
#                      street_to oci_desc
# 0                  ROBB ROY PL     Fair
# 1                         J ST     Poor
# 2                 IRVINGTON AV     Good
# 3                    THOMAS AV     Poor
# 4                    QUINCE ST     Poor
# 5                CITY BOUNDARY     Good
# 6                   DEL SUR BL     Good
# 7                  ROCHDALE LN     Good
# 8                          END     Fair
# 9                      20TH ST     Fair
# 10                     24TH ST     Poor
# 11              MEADOWBROOK CT     Good
# 12                        J ST     Poor
# 13              SAN VICENTE CT     Fair
# 14                     68TH ST     Poor
# 15                         END     Fair
# 16                         END     Fair
# 17                    BROADWAY     Fair
# 18                 WITHERBY ST     Poor
# 19               SUN MAIDEN CT     Fair
# 20                   FALCON ST     Good
# 21                  DOWNING LN     Good
# 22                 HIDEAWAY LN     Good
# 23               BELLA ROSA RD     Good
# 24                  MARINER DR     Fair
# 25                         END     Good
# 26                 TIVERTON RD     Good
# 27                      NOB AV     Fair
# 28               CRISSCROSS LN     Good
# 29                    PARMA LN     Fair
# ...                        ...      ...
# 28068            VIA MONTENERO     Good
# 28069               CASEY GLEN     Good
# 28070     OLD CARMEL VALLEY RD     Fair
# 28071             EXECUTIVE DR     Fair
# 28072         CORRIDOR SECTION     Fair
# 28073            LONE QUAIL RD     Fair
# 28074                      END     Good
# 28075            SEDERSTROM WY     Good
# 28076              LARKDALE PL     Good
# 28077             ZASLAVSKY PL     Good
# 28078                      END     Fair
# 28079               HAMMOND DR     Poor
# 28080          MURRAY RIDGE RD     Fair
# 28081                 AFTON RD     Fair
# 28082    MOONFLOWER MEADOWS TL     Good
# 28083  RANCHO SANTA FE FARM RD     Fair
# 28084                HORNET WY     Good
# 28085               CUSHING RD     Good
# 28086               TRUXTUN RD     Good
# 28087             GABLEWOOD WY     Fair
# 28088              DOMINION ST     Poor
# 28089              NATIONAL AV     Good
# 28090                ARDATH CT     Fair
# 28091         SILVER ACACIA PL     Good
# 28092              CAM PROPICO     Good
# 28093        RANCHO DEL SOL WY     Fair
# 28094      HISTORIC DECATUR RD     Good
# 28095           OLIVE KNOLL CT     Good
# 28096             OLD CREEK RD     Good
# 28097                      END     Good
#
# [28098 rows x 5 columns]

# %%
#Function to aply multiple conditions/regexp on string
def multiple_replace(dico, name_street):
  # Create a regular expression  from the dictionary keys
  regex = re.compile("(%s)" % "|".join(map(re.escape, dico.keys())))

  # For each match, look-up corresponding value in dictionary
  return (regex.sub(lambda mo: dico[mo.string[mo.start():mo.end()]], name_street) )

# %%
#MVA_DF put the street names in the closest format from the OCI dataset

pattern_digitAV = re.compile("^(^[0-9])([A-Z].*)") #If start with one digit and followed by str
dico = {"HWY" : "HY", "RT " : "I-","INTERSTATE ": "I-","STATE ROUTE ": "ST-"} 
for i in range(len(MVA_DF)) : #When finished, len(DF)
    #print("ONE  : ",(MVA_DF["PRIMARY_RD"])[i]," Intersection : ",(MVA_DF["SECONDARY_RD"])[i])
    (MVA_DF["PRIMARY_RD"])[i] = multiple_replace(dico,(MVA_DF["PRIMARY_RD"])[i]) #Get the street name
    (MVA_DF["SECONDARY_RD"])[i] = multiple_replace(dico,(MVA_DF["SECONDARY_RD"])[i]) #Get intersection 
    digit_AV_street = pattern_digitAV.match((MVA_DF["PRIMARY_RD"])[i]) # Check if match with pattern
    digit_AV_Inter =pattern_digitAV.match((MVA_DF["SECONDARY_RD"])[i]) # Check if match with pattern
    if digit_AV_Inter is not None : 
        (MVA_DF["SECONDARY_RD"])[i]= "0" + digit_AV_Inter.group()    #Add a 0 in front if match
    if digit_AV_street is not (None):
        (MVA_DF["PRIMARY_RD"])[i] = "0" + digit_AV_street.group() #Add a 0 in front if match
        
MVA_DF = MVA_DF.loc[MVA_DF.PCF_VIOL_CATEGORY != '1'] #If driving under drugs or alcohol
MVA_DF = MVA_DF[~(MVA_DF.PRIMARY_RD.str.startswith('I-'))] #Take off the accidents owhen on the main Interstates road but not if at intersection
MVA_DF = MVA_DF[~(MVA_DF.PRIMARY_RD.str.startswith('SR-'))] #Take off the accidents on State Routes (not in OCI df)

MVA_DF= MVA_DF.reset_index(drop=True)
#Interstate_Street_DF = MVA_DF[MVA_DF.PRIMARY_RD.str.startswith('RT')]
#Interstate_Street_DF
MVA_DF
# Out:
#      COLLISION_DATE COLLISION_TIME                         PRIMARY_RD  \
# 0          20150424           2235                            01ST AV
# 1          20150428           2008                       SEA WORLD DR
# 2          20150430           1418                  DEL MAR TRAILS RD
# 3          20150714           1831                        GRAMERCY DR
# 4          20150629           2145                      SOUTH 32ND ST
# 5          20150715           2129                        INGRAHAM ST
# 6          20150813           1823                          NAVAJO RD
# 7          20150822            730                          FRIARS RD
# 8          20150831           1726                           GRAND AV
# 9          20150830           1608                 CARMEL MOUNTAIN RD
# 10         20150829            955                        EL CAJON BL
# 11         20150915           1046                         GENESEE AV
# 12         20150926            220                       CLAIRMONT DR
# 13         20151220           2014                       ROSECRANS ST
# 14         20150107           1720                 RANCHO BERNARDO RD
# 15         20150111             13                         DEL SOL BL
# 16         20150115           1554                        RICHMOND ST
# 17         20150131           1807                      UNIVERSITY AV
# 18         20150103             25                           BACON ST
# 19         20150509           1108                         JAMACHA RD
# 20         20150105            955                         MIRAMAR RD
# 21         20150106           1539                         DENNERY RD
# 22         20150129            954                        HAWTHORN ST
# 23         20150127           1811                          RUFFIN RD
# 24         20150105           1626                          GARNET AV
# 25         20150105           1937                             ASH ST
# 26         20150103           1348                           TEXAS ST
# 27         20150106           1700                          BALBOA AV
# 28         20150102           1516                     LINDA VISTA RD
# 29         20150101           2230                            54TH ST
# ...             ...            ...                                ...
# 4604       20151212           1840                    ST-94 WESTBOUND
# 4605       20151205           1805                              I8 EB
# 4606       20151206           1410  I805 NB FROM TELEGRAPH CANYON RD.
# 4607       20151208           1900                          I -15 S/B
# 4608       20151209           1720                          SR 94 W/B
# 4609       20151102            708          9550 CARMEL MOUNTAIN ROAD
# 4610       20151207           1455                 COLLEGE AVENUE S/B
# 4611       20151214           1830                          SR 52 E/B
# 4612       20151216           1740                          I-805 S/B
# 4613       20151205           1210                            163 S/B
# 4614       20151212           1610      I805 NB TO I8 TRANSITION ROAD
# 4615       20151216           1740                         SR 163 S/B
# 4616       20151216           1750                         SR 163 S/B
# 4617       20151217           1520       PASEO LUCIDO N/B (13000 BLK)
# 4618       20151113           1235       VIA DE LA VALLE (2600 BLOCK)
# 4619       20151222           2140               N/B I-805 TO E/B I-8
# 4620       20151228           1600                          SR 52 E/B
# 4621       20151225           1630                    4375 DERRICK DR
# 4622       20151217           1525       PASEO LUCIDO N/B (13000 BLK)
# 4623       20151118           1522               04TH AVE (900 BLOCK)
# 4624       20151123           1410                         SR 163 S/B
# 4625       20151014            900                          ST-94 W/B
# 4626       20151103           1605                       ST-163 (S/B)
# 4627       20151025            252                   ST-15 SOUTHBOUND
# 4628       20151126            500                 N/B BRIARWOOD ROAD
# 4629       20151015            810                   ST-15 NORTHBOUND
# 4630       20151110           1435                          ST-15 N/B
# 4631       20151216            650                    CALLE QUEBRADA
# 4632       20151028            145                   ST-15 SOUTHBOUND
# 4633       20151224           2130                  ST-163 SOUTHBOUND
#
#               SECONDARY_RD CHP_BEAT_TYPE WEATHER_1 COLLISION_SEVERITY  \
# 0             W JUNIPER ST             0         B                  1
# 1           MISSION BAY DR             0         A                  1
# 2             MONA LISA ST             0         A                  1
# 3                TOWSER ST             0         A                  1
# 4            S 32ND ST 500             0         A                  1
# 5          DANA LANDING RD             0         A                  1
# 6             GOLFCREST DR             0         A                  1
# 7               PACIFIC HY             0         A                  1
# 8                 DAWES ST             0         A                  1
# 9          CARMEL CREEK RD             0         A                  1
# 10             ALTADENA AV             0         A                  1
# 11            CENTURION SQ             0         B                  1
# 12         RAPPAHANNOCK AV             0         A                  1
# 13           QUALTROUGH ST             0         A                  1
# 14                ACENA DR             0         A                  1
# 15               BEYER WAY             0         B                  1
# 16                ESSEX ST             0         A                  1
# 17                 47TH ST             0         B                  1
# 18             CORONADO AV             0         A                  1
# 19              GLENCOE DR             0         A                  1
# 20         MIRAMAR RD 7100             0         A                  3
# 21                 PALM AV             0         A                  4
# 22            ALBATROSS ST             0         A                  0
# 23             SKY PARK CT             0         A                  0
# 24               EVERTS ST             0         A                  4
# 25                 02ND AV             0         A                  4
# 26               MONROE AV             0         -                  3
# 27              RUFFNER ST             0         A                  3
# 28         MESA COLLEGE DR             0         A                  4
# 29           STREAMVIEW DR             0         A                  3
# ...                    ...           ...       ...                ...
# 4604     EUCLID AVENUE O/C             3         A                  0
# 4605             MORENA BL             1         A                  0
# 4606  TELEGRAPH CANYON RD.             1         A                  4
# 4607  CLAIREMONT MESA BLVD             1         A                  0
# 4608            KELTON AVE             3         A                  0
# 4609         SUN DEVIL WAY             S         B                  0
# 4610           LINDO PASEO             S         A                  0
# 4611             MAST BLVD             3         A                  4
# 4612             SR-15 U/C             1         A                  0
# 4613         ROBINSON AVE.             3         A                  0
# 4614        ADAMS AVE. O/C             1         A                  0
# 4615                   I-8             3         A                  0
# 4616                   I-8             3         A                  0
# 4617        CALLE SAUCILLO             S         A                  0
# 4618               I-5 N/B             S         A                  0
# 4619                   I-8             1         B                  0
# 4620             MAST BLVD             3         B                  0
# 4621       BALBOA ARMS DR.             A         A                  0
# 4622        CALLE SAUCILLO             S         A                  0
# 4623                  E ST             S         A                  0
# 4624         WASHINGTON ST             3         A                  4
# 4625           28TH STREET             3         B                  0
# 4626        GENESEE AVENUE             3         C                  4
# 4627     UNIVERSITY AVENUE             1         A                  1
# 4628           PICASSO DR.             5         C                  0
# 4629          ADAMS AVENUE             1         A                  1
# 4630  OCEAN VIEW BOULEVARD             1         A                  0
# 4631           GOETZE ROAD             S         A                  0
# 4632                 ST-94             1         A                  1
# 4633                   I-8             3         B                  1
#
#      PRIMARY_COLL_FACTOR PCF_VIOL_CATEGORY LIGHTING ROAD_SURFACE ROAD_COND_1
# 0                      A                 3        C            B           H
# 1                      A                11        E            A           H
# 2                      A                10        A            A           H
# 3                      A                 8        A            A           H
# 4                      A                 3        C            A           H
# 5                      A                11        C            A           H
# 6                      A                12        A            A           H
# 7                      A                 8        A            A           H
# 8                      A                10        A            A           H
# 9                      A                 3        A            A           H
# 10                     A                10        A            A           H
# 11                     A                 3        A            B           H
# 12                     A                 8        C            A           H
# 13                     A                 8        D            A           H
# 14                     A                10        B            A           H
# 15                     A                 8        C            A           H
# 16                     A                10        A            A           H
# 17                     A                11        C            A           H
# 18                     A                 3        C            A           H
# 19                     A                 8        A            A           H
# 20                     A                 3        A            A           H
# 21                     A                 3        A            A           H
# 22                     A                21        A            A           H
# 23                     A                 8        C            A           H
# 24                     A                 9        A            A           H
# 25                     A                 9        C            A           H
# 26                     A                 3        A            A           H
# 27                     A                 9        B            A           H
# 28                     A                 8        A            A           H
# 29                     A                 8        C            A           H
# ...                  ...               ...      ...          ...         ...
# 4604                   A                 8        C            A           H
# 4605                   A                 3        C            A           H
# 4606                   A                 3        A            A           H
# 4607                   A                 3        C            A           H
# 4608                   A                 3        C            A           H
# 4609                   B                22        A            A           H
# 4610                   A                 8        A            A           H
# 4611                   A                 3        D            A           H
# 4612                   A                 8        D            A           H
# 4613                   A                 3        A            A           H
# 4614                   A                 3        A            A           H
# 4615                   A                 3        C            A           H
# 4616                   A                 3        C            A           H
# 4617                   A                21        A            A           H
# 4618                   A                 8        A            A           H
# 4619                   A                 3        C            B           H
# 4620                   A                 3        A            B           H
# 4621                   A                21        C            A           H
# 4622                   A                 6        A            A           H
# 4623                   C                18        A            A           D
# 4624                   A                 7        A            A           H
# 4625                   A                 4        A            A           H
# 4626                   A                 3        A            B           H
# 4627                   A                 8        C            A           H
# 4628                   A                 8        C            B           H
# 4629                   A                 8        A            A           H
# 4630                   D                 0        A            A           H
# 4631                   A                 8        A            A           H
# 4632                   A                11        D            A           H
# 4633                   A                11        D            B           H
#
# [4634 rows x 12 columns]

# %%
#To be changed - Instead of looping wanted to merge on street name but don't think its possible - So we should make multiple conditions for determining if street + intersection corresponds to the right OCI
#If we have info on To or From  - look directly into the right street-to or street_from - 
#Otherwise, if double answers, check if same OCI_desc - if same just add it - Otherwise should we include it or just exclude these cases ? 

TEMP = pd.DataFrame(data=None, index=None, columns= None, dtype=None) #New empty dataframe
TEMP2 = pd.DataFrame(data=None, index=None, columns= None, dtype=None) #New empty dataframe
DF = pd.DataFrame(data=None, index=None, columns= None, dtype=None) #New empty dataframe
street_len = 0
intersection_len = 0

for i in range(len(MVA_DF)) : 
    street_name = (MVA_DF["PRIMARY_RD"])[i]
    intersection = (MVA_DF["SECONDARY_RD"])[i]
    
    TEMP = DF_OCI.loc[(DF_OCI['street']==(street_name))]
    
    if TEMP.empty:
        Close_Match_Street = (difflib.get_close_matches(street_name, (DF_OCI['street']),n=1))
        if (Close_Match_Street != []) : 
            TEMP = DF_OCI.loc(DF_OCI['street'] == Close_Match_Street[0])
        else :
            print("No street match")
            print("Street : ",street_name," Intersection : ",intersection)
            street_len = street_len +1
            
    else :
        TEMP2 = TEMP.loc[(TEMP['street_from'] == intersection)|(TEMP['street_to']==(intersection))]  
        if TEMP2.empty : 
            Close_Match_Intersection = (difflib.get_close_matches(intersection, (TEMP['street_from']),n=1))
            Close_Match_To = (difflib.get_close_matches(intersection, (TEMP['street_to']),n=1))
            #print("Close_match : ")
            #print(Close_Match_Intersection,Close_Match_To)
            if (Close_Match_Intersection != []) & (Close_Match_To != []) : 
                TEMP2 = TEMP.loc[(TEMP['street_from'] == Close_Match_Intersection[0])|(TEMP['street_to']== Close_Match_To[0])]
            elif (Close_Match_Intersection != []) : 
                TEMP2 = TEMP.loc[(TEMP['street_from'] == Close_Match_Intersection[0])]
            elif (Close_Match_To != []) : 
                TEMP2 = TEMP.loc[(TEMP['street_to'] == Close_Match_To[0])]
            else : 
                print("No street_from match")
                print("Street : ",street_name," Intersection : ",intersection)
                
        
        TEMP2= TEMP2.reset_index(drop=True)
        length = len(TEMP2)
        if length ==1 :
            DF = DF.append(TEMP2)
        elif length >1 : 
            if (TEMP2['oci_desc'])[0] == (TEMP2['oci_desc'])[1]:
                DF = DF.append(TEMP2.loc[[1]])
        else :
            print("no match at all")
            print("Street : ",street_name," Intersection : ",intersection)
            intersection_len = intersection_len +1
# Out:
# No street_from match
# Street :  GENESEE AV  Intersection :  CENTURION SQ
# no match at all
# Street :  GENESEE AV  Intersection :  CENTURION SQ
# No street_from match
# Street :  HAWTHORN ST  Intersection :  ALBATROSS ST
# no match at all
# Street :  HAWTHORN ST  Intersection :  ALBATROSS ST
# No street_from match
# Street :  CABLE ST  Intersection :  CABLE ST 1783
# no match at all
# Street :  CABLE ST  Intersection :  CABLE ST 1783
# No street_from match
# Street :  BERNARDO CENTER DR  Intersection :  I-15
# no match at all
# Street :  BERNARDO CENTER DR  Intersection :  I-15
# No street_from match
# Street :  HOWARD AV  Intersection :  SAN YSIDRO BL
# no match at all
# Street :  HOWARD AV  Intersection :  SAN YSIDRO BL
# No street_from match
# Street :  58TH ST  Intersection :  58TH ST 4000
# no match at all
# Street :  58TH ST  Intersection :  58TH ST 4000
# No street_from match
# Street :  UNIVERSITY AV  Intersection :  UNIVERSITY AV 5000
# no match at all
# Street :  UNIVERSITY AV  Intersection :  UNIVERSITY AV 5000
# No street_from match
# Street :  ADRIAN ST  Intersection :  WEST POINT LOMA BL
# no match at all
# Street :  ADRIAN ST  Intersection :  WEST POINT LOMA BL
# No street_from match
# Street :  PARK BL  Intersection :  SPACE THEATER WY
# no match at all
# Street :  PARK BL  Intersection :  SPACE THEATER WY
# No street_from match
# Street :  BEYER BL  Intersection :  WEST PARK
# no match at all
# Street :  BEYER BL  Intersection :  WEST PARK
# No street_from match
# Street :  CARROLL CANYON RD  Intersection :  I-15
# no match at all
# Street :  CARROLL CANYON RD  Intersection :  I-15
# No street_from match
# Street :  NORMAL ST  Intersection :  PARK BL
# no match at all
# Street :  NORMAL ST  Intersection :  PARK BL
# No street_from match
# Street :  SUNSET CLIFFS BL  Intersection :  I-8
# no match at all
# Street :  SUNSET CLIFFS BL  Intersection :  I-8
# No street_from match
# Street :  MIRAMAR RD  Intersection :  I-805
# no match at all
# Street :  MIRAMAR RD  Intersection :  I-805
# No street_from match
# Street :  SANTO RD  Intersection :  SANTO RD 5900
# no match at all
# Street :  SANTO RD  Intersection :  SANTO RD 5900
# No street_from match
# Street :  LINDA VISTA RD  Intersection :  LINDA VISTA RD 8000
# no match at all
# Street :  LINDA VISTA RD  Intersection :  LINDA VISTA RD 8000
# No street_from match
# Street :  EL CAJON BL  Intersection :  EL CAJON BL 6517
# no match at all
# Street :  EL CAJON BL  Intersection :  EL CAJON BL 6517
# No street_from match
# Street :  NORTH TORREY PINES RD  Intersection :  CARMEL VALLEY RD
# no match at all
# Street :  NORTH TORREY PINES RD  Intersection :  CARMEL VALLEY RD
# No street_from match
# Street :  32ND ST  Intersection :  NORMAN SCOTT RD
# no match at all
# Street :  32ND ST  Intersection :  NORMAN SCOTT RD
# No street_from match
# Street :  FAIRMOUNT AV  Intersection :  SUMAC DR
# no match at all
# Street :  FAIRMOUNT AV  Intersection :  SUMAC DR
# No street_from match
# Street :  MERCY RD  Intersection :  I-15
# no match at all
# Street :  MERCY RD  Intersection :  I-15
# No street_from match
# Street :  UNIVERSITY AV  Intersection :  UNIVERSITY AV 1000
# no match at all
# Street :  UNIVERSITY AV  Intersection :  UNIVERSITY AV 1000
# No street_from match
# Street :  SORRENTO VALLEY BL  Intersection :  PENASQUITOS WEST ENT
# no match at all
# Street :  SORRENTO VALLEY BL  Intersection :  PENASQUITOS WEST ENT
# No street_from match
# Street :  KURTZ ST  Intersection :  KURTZ ST 2700
# no match at all
# Street :  KURTZ ST  Intersection :  KURTZ ST 2700
# No street_from match
# Street :  MIDWAY DR  Intersection :  POST OFFICE DRIVEWAY
# no match at all
# Street :  MIDWAY DR  Intersection :  POST OFFICE DRIVEWAY
# No street_from match
# Street :  WEST MISSION BAY DR  Intersection :  SD LIGHT POST 165240
# no match at all
# Street :  WEST MISSION BAY DR  Intersection :  SD LIGHT POST 165240
# No street_from match
# Street :  GRAMERCY DR  Intersection :  RUFFIN RD
# no match at all
# Street :  GRAMERCY DR  Intersection :  RUFFIN RD
# No street_from match
# Street :  CORONADO AV  Intersection :  THERMAL AV
# no match at all
# Street :  CORONADO AV  Intersection :  THERMAL AV
# No street_from match
# Street :  54TH ST  Intersection :  WESTOVER PL
# no match at all
# Street :  54TH ST  Intersection :  WESTOVER PL
# No street_from match
# Street :  EL CAJON BL  Intersection :  ALICE ST
# no match at all
# Street :  EL CAJON BL  Intersection :  ALICE ST
# No street_from match
# Street :  MESA COLLEGE DR  Intersection :  I-163
# no match at all
# Street :  MESA COLLEGE DR  Intersection :  I-163
# No street_from match
# Street :  MIRAMAR RD  Intersection :  I-805
# no match at all
# Street :  MIRAMAR RD  Intersection :  I-805
# No street_from match
# Street :  EL CAJON BL  Intersection :  I-15
# no match at all
# Street :  EL CAJON BL  Intersection :  I-15
# No street_from match
# Street :  HEALTH CENTER DR  Intersection :  MARY BIRCH LN
# no match at all
# Street :  HEALTH CENTER DR  Intersection :  MARY BIRCH LN
# No street_from match
# Street :  EL CAJON BL  Intersection :  ROLANDO BL
# no match at all
# Street :  EL CAJON BL  Intersection :  ROLANDO BL
# No street_from match
# Street :  MORENA BL  Intersection :  I-8
# no match at all
# Street :  MORENA BL  Intersection :  I-8
# No street_from match
# Street :  FEDERAL BL  Intersection :  FEDERAL BL 4704
# no match at all
# Street :  FEDERAL BL  Intersection :  FEDERAL BL 4704
# No street_from match
# Street :  UNIVERSITY AV  Intersection :  UNIVERSITY AV 4400
# no match at all
# Street :  UNIVERSITY AV  Intersection :  UNIVERSITY AV 4400
# No street_from match
# Street :  POMERADO RD  Intersection :  I-15
# no match at all
# Street :  POMERADO RD  Intersection :  I-15
# No street_from match
# Street :  UNIVERSITY AV  Intersection :  I-15
# no match at all
# Street :  UNIVERSITY AV  Intersection :  I-15
# No street_from match
# Street :  REGENTS RD  Intersection :  MIRAMAR ST
# no match at all
# Street :  REGENTS RD  Intersection :  MIRAMAR ST
# No street_from match
# Street :  BOUNDARY ST  Intersection :  ADAMS AV
# no match at all
# Street :  BOUNDARY ST  Intersection :  ADAMS AV
# No street_from match
# Street :  RANCHO MISSION RD  Intersection :  CAMINITO CUERVO
# no match at all
# Street :  RANCHO MISSION RD  Intersection :  CAMINITO CUERVO
# No street_from match
# Street :  NORTH HARBOR DR  Intersection :  RENTAL CAR ACCESS  RD
# no match at all
# Street :  NORTH HARBOR DR  Intersection :  RENTAL CAR ACCESS  RD
# No street_from match
# Street :  MISSION BAY DR  Intersection :  OLLIE ST
# no match at all
# Street :  MISSION BAY DR  Intersection :  OLLIE ST
# No street_from match
# Street :  GOVERNOR DR  Intersection :  I-805
# no match at all
# Street :  GOVERNOR DR  Intersection :  I-805
# No street_from match
# Street :  EL CAJON BL  Intersection :  EL CERRITO
# no match at all
# Street :  EL CAJON BL  Intersection :  EL CERRITO
# No street_from match
# Street :  DIVISION ST  Intersection :  HIGHLAND AV
# no match at all
# Street :  DIVISION ST  Intersection :  HIGHLAND AV
# No street_from match
# Street :  SCRIPPS LAKE DR  Intersection :  SCRIPPS LAKE DR 10700
# no match at all
# Street :  SCRIPPS LAKE DR  Intersection :  SCRIPPS LAKE DR 10700
# No street_from match
# Street :  OLNEY ST  Intersection :  OLNEY ST 4400
# no match at all
# Street :  OLNEY ST  Intersection :  OLNEY ST 4400
# No street_from match
# Street :  B ST  Intersection :  I-5
# no match at all
# Street :  B ST  Intersection :  I-5
# No street_from match
# Street :  NAVAJO RD  Intersection :  I-125
# no match at all
# Street :  NAVAJO RD  Intersection :  I-125
# No street_from match
# Street :  COLLEGE AV  Intersection :  ZURA WY
# no match at all
# Street :  COLLEGE AV  Intersection :  ZURA WY
# No street_from match
# Street :  MIRA MESA BL  Intersection :  MIRA MESA BL 8200
# no match at all
# Street :  MIRA MESA BL  Intersection :  MIRA MESA BL 8200
# No street_from match
# Street :  COLLEGE AV  Intersection :  GOLLEGE AV 3300
# no match at all
# Street :  COLLEGE AV  Intersection :  GOLLEGE AV 3300
# No street_from match
# Street :  EL CAJON BL  Intersection :  I-805
# no match at all
# Street :  EL CAJON BL  Intersection :  I-805
# No street_from match
# Street :  BERNARDO CENTER DR  Intersection :  I-15
# no match at all
# Street :  BERNARDO CENTER DR  Intersection :  I-15
# No street_from match
# Street :  54TH ST  Intersection :  WESTOVER PL
# no match at all
# Street :  54TH ST  Intersection :  WESTOVER PL
# No street_from match
# Street :  26TH ST  Intersection :  RUSS BL
# no match at all
# Street :  26TH ST  Intersection :  RUSS BL
# No street_from match
# Street :  MIRA MESA BL  Intersection :  I-15
# no match at all
# Street :  MIRA MESA BL  Intersection :  I-15
# No street_from match
# Street :  AERO DR  Intersection :  AERO DR 9986
# no match at all
# Street :  AERO DR  Intersection :  AERO DR 9986
# No street_from match
# Street :  FRONT ST  Intersection :  W MONTECITO WY
# no match at all
# Street :  FRONT ST  Intersection :  W MONTECITO WY
# No street_from match
# Street :  UNIVERSITY AV  Intersection :  UNIVERSITY AV 1090
# no match at all
# Street :  UNIVERSITY AV  Intersection :  UNIVERSITY AV 1090
# No street_from match
# Street :  UNIVERSITY AV  Intersection :  VAN DYKE AV AND EAST ALLEY
# no match at all
# Street :  UNIVERSITY AV  Intersection :  VAN DYKE AV AND EAST ALLEY
# No street_from match
# Street :  EAST MISSION BAY DR  Intersection :  FIESTA ISLAND RD
# no match at all
# Street :  EAST MISSION BAY DR  Intersection :  FIESTA ISLAND RD
# No street_from match
# Street :  MERCY RD  Intersection :  I-15
# no match at all
# Street :  MERCY RD  Intersection :  I-15
# No street_from match
# Street :  TORREY PINES RD  Intersection :  GENESEE AV
# no match at all
# Street :  TORREY PINES RD  Intersection :  GENESEE AV
# No street_from match
# Street :  NORTH HARBOR DR  Intersection :  WEST BROADWAY
# no match at all
# Street :  NORTH HARBOR DR  Intersection :  WEST BROADWAY
# No street_from match
# Street :  CORONADO AV  Intersection :  RAEDEL DR
# no match at all
# Street :  CORONADO AV  Intersection :  RAEDEL DR
# No street_from match
# Street :  EL CAJON BL  Intersection :  EL CERRITO
# no match at all
# Street :  EL CAJON BL  Intersection :  EL CERRITO
# No street_from match
# Street :  NOBEL DR  Intersection :  UNIVERSITY CENTER LN
# no match at all
# Street :  NOBEL DR  Intersection :  UNIVERSITY CENTER LN
# No street_from match
# Street :  MISSION BAY DR  Intersection :  I-5
# no match at all
# Street :  MISSION BAY DR  Intersection :  I-5
# No street_from match
# Street :  KEARNY VILLA RD  Intersection :  I-163
# no match at all
# Street :  KEARNY VILLA RD  Intersection :  I-163
# No street_from match
# Street :  NORTH HARBOR DR  Intersection :  LEE CT
# no match at all
# Street :  NORTH HARBOR DR  Intersection :  LEE CT
# No street_from match
# Street :  LINDA VISTA RD  Intersection :  7400 LINDA VISTA RD
# no match at all
# Street :  LINDA VISTA RD  Intersection :  7400 LINDA VISTA RD
# No street_from match
# Street :  POMERADO RD  Intersection :  CHABAD CTR DRWY
# no match at all
# Street :  POMERADO RD  Intersection :  CHABAD CTR DRWY
# No street_from match
# Street :  GRAPE ST  Intersection :  PACIFIC HY
# no match at all
# Street :  GRAPE ST  Intersection :  PACIFIC HY
# No street_from match
# Street :  MIRA MESA BL  Intersection :  MIRA MESA BL 5300
# no match at all
# Street :  MIRA MESA BL  Intersection :  MIRA MESA BL 5300
# No street_from match
# Street :  CARMEL VALLEY RD  Intersection :  COUNTRY VILLAS PL
# no match at all
# Street :  CARMEL VALLEY RD  Intersection :  COUNTRY VILLAS PL
# No street_from match
# Street :  HOTEL CIRCLE SOUTH  Intersection :  BACHMAN PL
# no match at all
# Street :  HOTEL CIRCLE SOUTH  Intersection :  BACHMAN PL
# No street_from match
# Street :  GENESEE AV  Intersection :  I-52
# no match at all
# Street :  GENESEE AV  Intersection :  I-52
# No street_from match
# Street :  LA JOLLA SHORES DR  Intersection :  NAGA WY
# no match at all
# Street :  LA JOLLA SHORES DR  Intersection :  NAGA WY
# No street_from match
# Street :  26TH ST  Intersection :  RUSS BL
# no match at all
# Street :  26TH ST  Intersection :  RUSS BL
# No street_from match
# Street :  TOWNE CENTRE DR  Intersection :  TOWN CENTER GATEWAY 9100
# no match at all
# Street :  TOWNE CENTRE DR  Intersection :  TOWN CENTER GATEWAY 9100
# No street_from match
# Street :  CALLE PRIMERA  Intersection :  FIRE HYDRANT #850
# no match at all
# Street :  CALLE PRIMERA  Intersection :  FIRE HYDRANT #850
# No street_from match
# Street :  FRIARS RD  Intersection :  I-15
# no match at all
# Street :  FRIARS RD  Intersection :  I-15
# No street_from match
# Street :  GENESEE AV  Intersection :  I-52
# no match at all
# Street :  GENESEE AV  Intersection :  I-52
# No street_from match
# Street :  CARMEL COUNTRY RD  Intersection :  MEADOWS DEL MAR
# no match at all
# Street :  CARMEL COUNTRY RD  Intersection :  MEADOWS DEL MAR
# No street_from match
# Street :  CORONADO AV  Intersection :  BEYER BL
# no match at all
# Street :  CORONADO AV  Intersection :  BEYER BL
# No street_from match
# Street :  DENNERY RD  Intersection :  DEL SOL BL
# no match at all
# Street :  DENNERY RD  Intersection :  DEL SOL BL
# No street_from match
# Street :  LINDA VISTA RD  Intersection :  LINDA VISTA
# no match at all
# Street :  LINDA VISTA RD  Intersection :  LINDA VISTA
# No street_from match
# Street :  S 38TH ST  Intersection :  S 38TH ST 450
# no match at all
# Street :  S 38TH ST  Intersection :  S 38TH ST 450
# No street_from match
# Street :  DAMON AV  Intersection :  MISSION BAY DR
# no match at all
# Street :  DAMON AV  Intersection :  MISSION BAY DR
# No street_from match
# Street :  CARMEL VALLEY RD  Intersection :  OLD CARMEL VALLEY RD
# no match at all
# Street :  CARMEL VALLEY RD  Intersection :  OLD CARMEL VALLEY RD
# No street_from match
# Street :  10TH AV  Intersection :  FAIRMONT AV
# no match at all
# Street :  10TH AV  Intersection :  FAIRMONT AV
# No street_from match
# Street :  FAIRMOUNT AV  Intersection :  I-8
# no match at all
# Street :  FAIRMOUNT AV  Intersection :  I-8
# No street_from match
# Street :  BALBOA AV  Intersection :  TERRY BENNETT DRWY
# no match at all
# Street :  BALBOA AV  Intersection :  TERRY BENNETT DRWY
# No street_from match
# Street :  GENESEE AV  Intersection :  I-162
# no match at all
# Street :  GENESEE AV  Intersection :  I-162
# No street_from match
# Street :  SEA WORLD DR  Intersection :  I-5
# no match at all
# Street :  SEA WORLD DR  Intersection :  I-5
# No street_from match
# Street :  CARGILL AV  Intersection :  CAMINO MILITA
# no match at all
# Street :  CARGILL AV  Intersection :  CAMINO MILITA
# No street_from match
# Street :  BUSINESS CENTER CT  Intersection :  BUSINESS CENTER DR
# no match at all
# Street :  BUSINESS CENTER CT  Intersection :  BUSINESS CENTER DR
# No street_from match
# Street :  CORONADO AV  Intersection :  OUTER RD
# no match at all
# Street :  CORONADO AV  Intersection :  OUTER RD
# No street_from match
# Street :  MIRAMAR RD  Intersection :  MILCH RD 9400
# no match at all
# Street :  MIRAMAR RD  Intersection :  MILCH RD 9400
# No street_from match
# Street :  DOVE ST  Intersection :  DOVE ST 3900
# no match at all
# Street :  DOVE ST  Intersection :  DOVE ST 3900
# No street_from match
# Street :  ROBINSON AV  Intersection :  PARK BL
# no match at all
# Street :  ROBINSON AV  Intersection :  PARK BL
# No street_from match
# Street :  KEARNY VILLA RD  Intersection :  WAXIE WY
# no match at all
# Street :  KEARNY VILLA RD  Intersection :  WAXIE WY
# No street_from match
# Street :  MIDWAY DR  Intersection :  EAST DR
# no match at all
# Street :  MIDWAY DR  Intersection :  EAST DR
# No street_from match
# Street :  COLLEGE AV  Intersection :  EAST WALL OF PS1
# no match at all
# Street :  COLLEGE AV  Intersection :  EAST WALL OF PS1
# No street_from match
# Street :  AERO DR  Intersection :  I-15
# no match at all
# Street :  AERO DR  Intersection :  I-15
# No street_from match
# Street :  DEL MAR HEIGHTS RD  Intersection :  I-5
# no match at all
# Street :  DEL MAR HEIGHTS RD  Intersection :  I-5
# No street_from match
# Street :  MARKET ST  Intersection :  MARKET ST 600
# no match at all
# Street :  MARKET ST  Intersection :  MARKET ST 600
# No street_from match
# Street :  MIRAMAR RD  Intersection :  I-805
# no match at all
# Street :  MIRAMAR RD  Intersection :  I-805
# No street_from match
# Street :  10TH AV  Intersection :  10TH AV 3800
# no match at all
# Street :  10TH AV  Intersection :  10TH AV 3800
# No street_from match
# Street :  TAYLOR ST  Intersection :  TAYLOR ST 4000
# no match at all
# Street :  TAYLOR ST  Intersection :  TAYLOR ST 4000
# No street_from match
# Street :  MIRA MESA BL  Intersection :  I-15
# no match at all
# Street :  MIRA MESA BL  Intersection :  I-15
# No street_from match
# Street :  VIA DE LA VALLE  Intersection :  SANTA FE DOWNS
# no match at all
# Street :  VIA DE LA VALLE  Intersection :  SANTA FE DOWNS
# No street_from match
# Street :  SEA WORLD DR  Intersection :  PACIFIC HY
# no match at all
# Street :  SEA WORLD DR  Intersection :  PACIFIC HY
# No street_from match
# Street :  WEST POINT LOMA BL  Intersection :  WEST POINT LOMA BL 4364
# no match at all
# Street :  WEST POINT LOMA BL  Intersection :  WEST POINT LOMA BL 4364
# No street_from match
# Street :  ROSECRANS ST  Intersection :  HARBOR DR
# no match at all
# Street :  ROSECRANS ST  Intersection :  HARBOR DR
# No street_from match
# Street :  PACIFIC HY  Intersection :  ENTERPRISE ST
# no match at all
# Street :  PACIFIC HY  Intersection :  ENTERPRISE ST
# No street_from match
# Street :  WEST MISSION BAY DR  Intersection :  GLEASON RD
# no match at all
# Street :  WEST MISSION BAY DR  Intersection :  GLEASON RD
# No street_from match
# Street :  MONTEZUMA RD  Intersection :  FAIRMOUNT AV
# no match at all
# Street :  MONTEZUMA RD  Intersection :  FAIRMOUNT AV
# No street_from match
# Street :  HIGHLAND VALLEY RD  Intersection :  HIGHLAND VALLEY RD 14103
# no match at all
# Street :  HIGHLAND VALLEY RD  Intersection :  HIGHLAND VALLEY RD 14103
# No street_from match
# Street :  AERO DR  Intersection :  I-15
# no match at all
# Street :  AERO DR  Intersection :  I-15
# No street_from match
# Street :  FASHION VALLEY RD  Intersection :  RIVERWALK DR
# no match at all
# Street :  FASHION VALLEY RD  Intersection :  RIVERWALK DR
# No street_from match
# Street :  WEST MISSION BAY DR  Intersection :  I-8
# no match at all
# Street :  WEST MISSION BAY DR  Intersection :  I-8
# No street_from match
# Street :  WEST MISSION BAY DR  Intersection :  QUIVIRA RD
# no match at all
# Street :  WEST MISSION BAY DR  Intersection :  QUIVIRA RD
# No street_from match
# Street :  WOODMAN ST  Intersection :  BRANDYWOOD ST
# no match at all
# Street :  WOODMAN ST  Intersection :  BRANDYWOOD ST
# No street_from match
# Street :  CLAIREMONT MESA BL  Intersection :  MISSION TRAILS REGIONAL PARK ENT
# no match at all
# Street :  CLAIREMONT MESA BL  Intersection :  MISSION TRAILS REGIONAL PARK ENT
# No street_from match
# Street :  EUCLID AV  Intersection :  MARILOU RD
# no match at all
# Street :  EUCLID AV  Intersection :  MARILOU RD
# No street_from match
# Street :  NORTH TORREY PINES RD  Intersection :  SCIENCE PARK RD
# no match at all
# Street :  NORTH TORREY PINES RD  Intersection :  SCIENCE PARK RD
# No street_from match
# Street :  WEST MISSION BAY DR  Intersection :  GLEASON RD
# no match at all
# Street :  WEST MISSION BAY DR  Intersection :  GLEASON RD
# No street_from match
# Street :  MAIN ST  Intersection :  I-5
# no match at all
# Street :  MAIN ST  Intersection :  I-5
# No street_from match
# Street :  NORTH HARBOR DR  Intersection :  CELL PHONE LOT ENTRANCE
# no match at all
# Street :  NORTH HARBOR DR  Intersection :  CELL PHONE LOT ENTRANCE
# No street_from match
# Street :  MAIN ST  Intersection :  YAMA ST 2100
# no match at all
# Street :  MAIN ST  Intersection :  YAMA ST 2100
# No street_from match
# Street :  10TH AV  Intersection :  10TH AV 500
# no match at all
# Street :  10TH AV  Intersection :  10TH AV 500
# No street_from match
# Street :  LINDA VISTA RD  Intersection :  ALCALA PARK
# no match at all
# Street :  LINDA VISTA RD  Intersection :  ALCALA PARK
# No street_from match
# Street :  EUCLID AV  Intersection :  UNITY PLACE DR
# no match at all
# Street :  EUCLID AV  Intersection :  UNITY PLACE DR
# No street_from match
# Street :  PLAZA DE PALMAS  Intersection :  REGENTS RD
# no match at all
# Street :  PLAZA DE PALMAS  Intersection :  REGENTS RD
# No street_from match
# Street :  GILMAN DR  Intersection :  EVENING WY
# no match at all
# Street :  GILMAN DR  Intersection :  EVENING WY
# No street_from match
# Street :  POMERADO RD  Intersection :  CAMTO ALTO
# no match at all
# Street :  POMERADO RD  Intersection :  CAMTO ALTO
# No street_from match
# Street :  EUCLID AV  Intersection :  I-94
# no match at all
# Street :  EUCLID AV  Intersection :  I-94
# No street_from match
# Street :  EAST MISSION BAY DR  Intersection :  EAST MISSION BAY DR 1775
# no match at all
# Street :  EAST MISSION BAY DR  Intersection :  EAST MISSION BAY DR 1775
# No street_from match
# Street :  OTAY MESA RD  Intersection :  I-125
# no match at all
# Street :  OTAY MESA RD  Intersection :  I-125
# No street_from match
# Street :  ILLINOIS ST  Intersection :  ILLINOIS ST 4400
# no match at all
# Street :  ILLINOIS ST  Intersection :  ILLINOIS ST 4400
# No street_from match
# Street :  HIGH BLUFF DR  Intersection :  PLAZA DEL MAR
# no match at all
# Street :  HIGH BLUFF DR  Intersection :  PLAZA DEL MAR
# No street_from match
# Street :  OTAY MESA RD  Intersection :  I-125
# no match at all
# Street :  OTAY MESA RD  Intersection :  I-125
# No street match
# Street :  R  Intersection :  CARMEL VALLEY RD
# No street_from match
# Street :  CARMEL VALLEY RD  Intersection :  I-5
# no match at all
# Street :  CARMEL VALLEY RD  Intersection :  I-5
# No street_from match
# Street :  NOBEL DR  Intersection :  I-5
# no match at all
# Street :  NOBEL DR  Intersection :  I-5
# No street_from match
# Street :  70TH ST  Intersection :  COLONY RD
# no match at all
# Street :  70TH ST  Intersection :  COLONY RD
# No street_from match
# Street :  COSTA VERDE BL  Intersection :  NOBEL DR
# no match at all
# Street :  COSTA VERDE BL  Intersection :  NOBEL DR
# No street_from match
# Street :  SORRENTO VALLEY RD  Intersection :  SEA MIST WY
# no match at all
# Street :  SORRENTO VALLEY RD  Intersection :  SEA MIST WY
# No street_from match
# Street :  AERO DR  Intersection :  AERO DR 8825
# no match at all
# Street :  AERO DR  Intersection :  AERO DR 8825
# No street_from match
# Street :  CARMEL COUNTRY RD  Intersection :  I-56
# no match at all
# Street :  CARMEL COUNTRY RD  Intersection :  I-56
# No street_from match
# Street :  SEA WORLD DR  Intersection :  PACIFIC HY
# no match at all
# Street :  SEA WORLD DR  Intersection :  PACIFIC HY
# No street_from match
# Street :  CLAIREMONT MESA BL  Intersection :  INDUSTRIAL PARK DRWY
# no match at all
# Street :  CLAIREMONT MESA BL  Intersection :  INDUSTRIAL PARK DRWY
# No street_from match
# Street :  CLAIREMONT MESA BL  Intersection :  I-805
# no match at all
# Street :  CLAIREMONT MESA BL  Intersection :  I-805
# No street_from match
# Street :  POMERADO RD  Intersection :  I-15
# no match at all
# Street :  POMERADO RD  Intersection :  I-15
# No street_from match
# Street :  CLAIREMONT MESA BL  Intersection :  I-805
# no match at all
# Street :  CLAIREMONT MESA BL  Intersection :  I-805
# No street_from match
# Street :  FRIARS RD  Intersection :  YMCA WEST DRIVEWAY
# no match at all
# Street :  FRIARS RD  Intersection :  YMCA WEST DRIVEWAY
# No street_from match
# Street :  LA JOLLA VILLAGE DR  Intersection :  I-805
# no match at all
# Street :  LA JOLLA VILLAGE DR  Intersection :  I-805
# No street_from match
# Street :  B ST  Intersection :  END ROADWAY
# no match at all
# Street :  B ST  Intersection :  END ROADWAY
# No street_from match
# Street :  DEL MAR HEIGHTS RD  Intersection :  HARTFIELD AV
# no match at all
# Street :  DEL MAR HEIGHTS RD  Intersection :  HARTFIELD AV
# No street_from match
# Street :  NORTH TORREY PINES RD  Intersection :  NU SYSTEMS DRIVEWAY
# no match at all
# Street :  NORTH TORREY PINES RD  Intersection :  NU SYSTEMS DRIVEWAY
# No street_from match
# Street :  PACIFIC HY  Intersection :  ENTERPRISE ST
# no match at all
# Street :  PACIFIC HY  Intersection :  ENTERPRISE ST
# No street_from match
# Street :  CORONADO AV  Intersection :  HOLLISTER ST
# no match at all
# Street :  CORONADO AV  Intersection :  HOLLISTER ST
# No street_from match
# Street :  PRESIDIO DR  Intersection :  PRESIDIO DR 2800
# no match at all
# Street :  PRESIDIO DR  Intersection :  PRESIDIO DR 2800
# No street_from match
# Street :  GENESEE AV  Intersection :  I-5
# no match at all
# Street :  GENESEE AV  Intersection :  I-5
# No street_from match
# Street :  CARROLL CANYON RD  Intersection :  I-15
# no match at all
# Street :  CARROLL CANYON RD  Intersection :  I-15
# No street_from match
# Street :  FRIARS RD  Intersection :  VIA DE LA MODA
# no match at all
# Street :  FRIARS RD  Intersection :  VIA DE LA MODA
# No street_from match
# Street :  SANTO RD  Intersection :  SHIELDS ST
# no match at all
# Street :  SANTO RD  Intersection :  SHIELDS ST
# No street_from match
# Street :  ORO VISTA RD  Intersection :  TOCAYO AV
# no match at all
# Street :  ORO VISTA RD  Intersection :  TOCAYO AV
# No street_from match
# Street :  CARMEL VALLEY RD  Intersection :  DOVE CANYON RD
# no match at all
# Street :  CARMEL VALLEY RD  Intersection :  DOVE CANYON RD
# No street_from match
# Street :  MERCY RD  Intersection :  I-15
# no match at all
# Street :  MERCY RD  Intersection :  I-15
# No street_from match
# Street :  GENESEE AV  Intersection :  I-5
# no match at all
# Street :  GENESEE AV  Intersection :  I-5
# No street_from match
# Street :  MARKET ST  Intersection :  I-15
# no match at all
# Street :  MARKET ST  Intersection :  I-15
# No street_from match
# Street :  16TH ST  Intersection :  16TH ST 455
# no match at all
# Street :  16TH ST  Intersection :  16TH ST 455
# No street_from match
# Street :  IMPERIAL AV  Intersection :  EDGEFIELD WY
# no match at all
# Street :  IMPERIAL AV  Intersection :  EDGEFIELD WY
# No street_from match
# Street :  MAIN ST  Intersection :  ALAMITOS
# no match at all
# Street :  MAIN ST  Intersection :  ALAMITOS
# No street_from match
# Street :  GILMAN DR  Intersection :  EVENING WY
# no match at all
# Street :  GILMAN DR  Intersection :  EVENING WY
# No street_from match
# Street :  SORRENTO VALLEY BL  Intersection :  CAMINO SANTA FE
# no match at all
# Street :  SORRENTO VALLEY BL  Intersection :  CAMINO SANTA FE
# No street_from match
# Street :  HIGHLAND VALLEY RD  Intersection :  POMERADO RD
# no match at all
# Street :  HIGHLAND VALLEY RD  Intersection :  POMERADO RD
# No street_from match
# Street :  GENESEE AV  Intersection :  SCRIPPS HOSPITAL DRWY
# no match at all
# Street :  GENESEE AV  Intersection :  SCRIPPS HOSPITAL DRWY
# No street_from match
# Street :  LINDA VISTA RD  Intersection :  OLRICK
# no match at all
# Street :  LINDA VISTA RD  Intersection :  OLRICK
# No street_from match
# Street :  MIRAMAR RD  Intersection :  I-805
# no match at all
# Street :  MIRAMAR RD  Intersection :  I-805
# No street_from match
# Street :  MISSION BL  Intersection :  BELMONT PARK
# no match at all
# Street :  MISSION BL  Intersection :  BELMONT PARK
# No street_from match
# Street :  DENNERY RD  Intersection :  WALMAI-DRWY
# no match at all
# Street :  DENNERY RD  Intersection :  WALMAI-DRWY
# No street_from match
# Street :  SPORTS ARENA BL  Intersection :  EAST DR
# no match at all
# Street :  SPORTS ARENA BL  Intersection :  EAST DR
# No street_from match
# Street :  16TH ST  Intersection :  16TH ST 300
# no match at all
# Street :  16TH ST  Intersection :  16TH ST 300
# No street_from match
# Street :  INGRAHAM ST  Intersection :  RIVIERA DR
# no match at all
# Street :  INGRAHAM ST  Intersection :  RIVIERA DR
# No street_from match
# Street :  TORREY PINES RD  Intersection :  GLENBROOK WY
# no match at all
# Street :  TORREY PINES RD  Intersection :  GLENBROOK WY
# No street_from match
# Street :  AFTON RD  Intersection :  KRENZ ST
# no match at all
# Street :  AFTON RD  Intersection :  KRENZ ST
# No street_from match
# Street :  WEST POINT LOMA BL  Intersection :  WEST POINT LOMA BL 4358
# no match at all
# Street :  WEST POINT LOMA BL  Intersection :  WEST POINT LOMA BL 4358
# No street_from match
# Street :  PASEO MONTE BATALLA  Intersection :  CAMINITO PASADERO
# no match at all
# Street :  PASEO MONTE BATALLA  Intersection :  CAMINITO PASADERO
# No street_from match
# Street :  POWAY RD  Intersection :  I-15
# no match at all
# Street :  POWAY RD  Intersection :  I-15
# No street_from match
# Street :  EL CAJON BL  Intersection :  I-805
# no match at all
# Street :  EL CAJON BL  Intersection :  I-805
# No street_from match
# Street :  HOME AV  Intersection :  I-805
# no match at all
# Street :  HOME AV  Intersection :  I-805
# No street_from match
# Street :  CLAIREMONT MESA BL  Intersection :  I-163
# no match at all
# Street :  CLAIREMONT MESA BL  Intersection :  I-163
# No street_from match
# Street :  SAN PASQUAL RD  Intersection :  TIERRA DE DIOS
# no match at all
# Street :  SAN PASQUAL RD  Intersection :  TIERRA DE DIOS
# No street_from match
# Street :  ORO VISTA RD  Intersection :  TOCAYO AV
# no match at all
# Street :  ORO VISTA RD  Intersection :  TOCAYO AV
# No street_from match
# Street :  CARROLL CANYON RD  Intersection :  I-15
# no match at all
# Street :  CARROLL CANYON RD  Intersection :  I-15
# No street_from match
# Street :  MIDWAY DR  Intersection :  LA JOLLA BL
# no match at all
# Street :  MIDWAY DR  Intersection :  LA JOLLA BL
# No street_from match
# Street :  54TH ST  Intersection :  WESTOVER PL
# no match at all
# Street :  54TH ST  Intersection :  WESTOVER PL
# No street_from match
# Street :  PERSHING DR  Intersection :  FLORIDA DR
# no match at all
# Street :  PERSHING DR  Intersection :  FLORIDA DR
# No street_from match
# Street :  KEARNY VILLA RD  Intersection :  I-163
# no match at all
# Street :  KEARNY VILLA RD  Intersection :  I-163
# No street_from match
# Street :  MERCY RD  Intersection :  I-15
# no match at all
# Street :  MERCY RD  Intersection :  I-15
# No street_from match
# Street :  BEYER BL  Intersection :  BOYSENBERRY CT
# no match at all
# Street :  BEYER BL  Intersection :  BOYSENBERRY CT
# No street_from match
# Street :  TAYLOR ST  Intersection :  I-8
# no match at all
# Street :  TAYLOR ST  Intersection :  I-8
# No street_from match
# Street :  BALBOA AV  Intersection :  PENNISI DY
# no match at all
# Street :  BALBOA AV  Intersection :  PENNISI DY
# No street_from match
# Street :  CANON ST  Intersection :  JENNINGS ST
# no match at all
# Street :  CANON ST  Intersection :  JENNINGS ST
# No street_from match
# Street :  HOTEL CIRCLE SOUTH  Intersection :  TAYLOR ST
# no match at all
# Street :  HOTEL CIRCLE SOUTH  Intersection :  TAYLOR ST
# No street_from match
# Street :  VIA DE LA VALLE  Intersection :  SANTA FE DOWNS
# no match at all
# Street :  VIA DE LA VALLE  Intersection :  SANTA FE DOWNS
# No street_from match
# Street :  MAIN ST  Intersection :  I-15
# no match at all
# Street :  MAIN ST  Intersection :  I-15
# No street_from match
# Street :  S 33RD ST  Intersection :  NORMAN SCOTT RD
# no match at all
# Street :  S 33RD ST  Intersection :  NORMAN SCOTT RD
# No street_from match
# Street :  CORONADO AV  Intersection :  30TH ST
# no match at all
# Street :  CORONADO AV  Intersection :  30TH ST
# No street_from match
# Street :  VIA DE LA VALLE  Intersection :  VALLEY AV
# no match at all
# Street :  VIA DE LA VALLE  Intersection :  VALLEY AV
# No street_from match
# Street :  HILLERY DR  Intersection :  HILLERY DR 9260
# no match at all
# Street :  HILLERY DR  Intersection :  HILLERY DR 9260
# No street_from match
# Street :  CALLE CRISTOBAL  Intersection :  LOPEZ RIDGE PK
# no match at all
# Street :  CALLE CRISTOBAL  Intersection :  LOPEZ RIDGE PK
# No street_from match
# Street :  MIRAMAR RD  Intersection :  I-15
# no match at all
# Street :  MIRAMAR RD  Intersection :  I-15
# No street_from match
# Street :  MAST BL  Intersection :  I-52
# no match at all
# Street :  MAST BL  Intersection :  I-52
# No street_from match
# Street :  TORREY PINES RD  Intersection :  POTTERY PARK
# no match at all
# Street :  TORREY PINES RD  Intersection :  POTTERY PARK
# No street_from match
# Street :  NATIONAL AV  Intersection :  NATIONAL AV 3600
# no match at all
# Street :  NATIONAL AV  Intersection :  NATIONAL AV 3600
# No street_from match
# Street :  COLLEGE AV  Intersection :  JUDY MCCARTY WY
# no match at all
# Street :  COLLEGE AV  Intersection :  JUDY MCCARTY WY
# No street_from match
# Street :  KEARNY VILLA RD  Intersection :  I-15
# no match at all
# Street :  KEARNY VILLA RD  Intersection :  I-15
# No street_from match
# Street :  54TH ST  Intersection :  4400 54TH ST
# no match at all
# Street :  54TH ST  Intersection :  4400 54TH ST
# No street_from match
# Street :  25TH ST  Intersection :  I-94
# no match at all
# Street :  25TH ST  Intersection :  I-94
# No street_from match
# Street :  HARDY AV  Intersection :  NORTH WALL
# no match at all
# Street :  HARDY AV  Intersection :  NORTH WALL
# No street_from match
# Street :  MORENA BL  Intersection :  GARNET AV
# no match at all
# Street :  MORENA BL  Intersection :  GARNET AV
# No street_from match
# Street :  TWINING AV  Intersection :  TWINING / DAVIS INTERSECTION
# no match at all
# Street :  TWINING AV  Intersection :  TWINING / DAVIS INTERSECTION
# No street_from match
# Street :  SPORTS ARENA BL  Intersection :  SPORTS ARENA BL 3200
# no match at all
# Street :  SPORTS ARENA BL  Intersection :  SPORTS ARENA BL 3200
# No street_from match
# Street :  NOBEL DR  Intersection :  UNIVERSITY CENTER LN
# no match at all
# Street :  NOBEL DR  Intersection :  UNIVERSITY CENTER LN
# No street_from match
# Street :  MONUMENT RD  Intersection :  MONUMENT RD 700
# no match at all
# Street :  MONUMENT RD  Intersection :  MONUMENT RD 700
# No street_from match
# Street :  GENESEE AV  Intersection :  SCRIPPS  HOSPITAL DR
# no match at all
# Street :  GENESEE AV  Intersection :  SCRIPPS  HOSPITAL DR
# No street_from match
# Street :  MIRA MESA BL  Intersection :  I-15
# no match at all
# Street :  MIRA MESA BL  Intersection :  I-15
# No street_from match
# Street :  MIRA MESA BL  Intersection :  SCHILLING  AV
# no match at all
# Street :  MIRA MESA BL  Intersection :  SCHILLING  AV
# No street_from match
# Street :  CORONADO AV  Intersection :  16TH ST
# no match at all
# Street :  CORONADO AV  Intersection :  16TH ST
# No street_from match
# Street :  MISSION BAY DR  Intersection :  SEA WORLD DR
# no match at all
# Street :  MISSION BAY DR  Intersection :  SEA WORLD DR
# No street_from match
# Street :  COLLEGE AV  Intersection :  JUDY MCCARTY WY
# no match at all
# Street :  COLLEGE AV  Intersection :  JUDY MCCARTY WY
# No street_from match
# Street :  43RD ST  Intersection :  DELTA ST
# no match at all
# Street :  43RD ST  Intersection :  DELTA ST
# No street_from match
# Street :  54TH ST  Intersection :  WESTOVER PL
# no match at all
# Street :  54TH ST  Intersection :  WESTOVER PL
# No street_from match
# Street :  54TH ST  Intersection :  WESTOVER PL
# no match at all
# Street :  54TH ST  Intersection :  WESTOVER PL
# No street_from match
# Street :  60TH ST  Intersection :  1000 60TH ST
# no match at all
# Street :  60TH ST  Intersection :  1000 60TH ST
# No street_from match
# Street :  MIDWAY DR  Intersection :  MIDWAY DR DRIVEWAY 2701
# no match at all
# Street :  MIDWAY DR  Intersection :  MIDWAY DR DRIVEWAY 2701
# No street_from match
# Street :  MIRA MESA BL  Intersection :  WESTMORE RD
# no match at all
# Street :  MIRA MESA BL  Intersection :  WESTMORE RD
# No street_from match
# Street :  WEST MISSION BAY DR  Intersection :  QUIVIRA RD
# no match at all
# Street :  WEST MISSION BAY DR  Intersection :  QUIVIRA RD
# No street_from match
# Street :  CANTER HEIGHTS DR  Intersection :  OCEAN AIR SCHOOL
# no match at all
# Street :  CANTER HEIGHTS DR  Intersection :  OCEAN AIR SCHOOL
# No street_from match
# Street :  MIRA MESA BL  Intersection :  I-15
# no match at all
# Street :  MIRA MESA BL  Intersection :  I-15
# No street_from match
# Street :  HOME AV  Intersection :  I-94
# no match at all
# Street :  HOME AV  Intersection :  I-94
# No street_from match
# Street :  MURRAY RIDGE RD  Intersection :  MURRAY RIDGE RD 3015
# no match at all
# Street :  MURRAY RIDGE RD  Intersection :  MURRAY RIDGE RD 3015
# No street_from match
# Street :  CLAIREMONT MESA BL  Intersection :  INDUSTRIAL PARK DRWY
# no match at all
# Street :  CLAIREMONT MESA BL  Intersection :  INDUSTRIAL PARK DRWY
# No street_from match
# Street :  MONTEZUMA RD  Intersection :  FAIREMONT
# no match at all
# Street :  MONTEZUMA RD  Intersection :  FAIREMONT
# No street_from match
# Street :  DEL MAR HEIGHTS RD  Intersection :  I-5
# no match at all
# Street :  DEL MAR HEIGHTS RD  Intersection :  I-5
# No street_from match
# Street :  MIDWAY DR  Intersection :  EAST DR
# no match at all
# Street :  MIDWAY DR  Intersection :  EAST DR
# No street_from match
# Street :  WORLD TRADE DR  Intersection :  WORLD TRADE DR 12000
# no match at all
# Street :  WORLD TRADE DR  Intersection :  WORLD TRADE DR 12000
# No street_from match
# Street :  TECOLOTE RD  Intersection :  TECOLOTE RD 4500
# no match at all
# Street :  TECOLOTE RD  Intersection :  TECOLOTE RD 4500
# No street_from match
# Street :  MIRAMAR RD  Intersection :  ALESMITH CT
# no match at all
# Street :  MIRAMAR RD  Intersection :  ALESMITH CT
# No street_from match
# Street :  NORTH HARBOR DR  Intersection :  LIGHT POLE #165240
# no match at all
# Street :  NORTH HARBOR DR  Intersection :  LIGHT POLE #165240
# No street_from match
# Street :  NORTH HARBOR DR  Intersection :  RENT A CAR ACCESS
# no match at all
# Street :  NORTH HARBOR DR  Intersection :  RENT A CAR ACCESS
# No street_from match
# Street :  HIGHLAND AV  Intersection :  W ALLY HIGHLAND 4000
# no match at all
# Street :  HIGHLAND AV  Intersection :  W ALLY HIGHLAND 4000
# No street_from match
# Street :  LINCOLN AV  Intersection :  LINCOLN AV 1800
# no match at all
# Street :  LINCOLN AV  Intersection :  LINCOLN AV 1800
# No street_from match
# Street :  MEADE AV  Intersection :  MEADE AV 2100
# no match at all
# Street :  MEADE AV  Intersection :  MEADE AV 2100
# No street_from match
# Street :  NORMAL ST  Intersection :  PARK BL
# no match at all
# Street :  NORMAL ST  Intersection :  PARK BL
# No street_from match
# Street :  ELM ST  Intersection :  ELM ST 200
# no match at all
# Street :  ELM ST  Intersection :  ELM ST 200
# No street_from match
# Street :  NOBEL DR  Intersection :  I-5
# no match at all
# Street :  NOBEL DR  Intersection :  I-5
# No street_from match
# Street :  GILMAN DR  Intersection :  I-5
# no match at all
# Street :  GILMAN DR  Intersection :  I-5
# No street_from match
# Street :  PACIFIC HY  Intersection :  TRIPOLI AV
# no match at all
# Street :  PACIFIC HY  Intersection :  TRIPOLI AV
# No street_from match
# Street :  PACIFIC HY  Intersection :  COUTS
# no match at all
# Street :  PACIFIC HY  Intersection :  COUTS
# No street_from match
# Street :  EL CAJON BL  Intersection :  CHOCTAW DR
# no match at all
# Street :  EL CAJON BL  Intersection :  CHOCTAW DR
# No street_from match
# Street :  CORONADO AV  Intersection :  18TH ST
# no match at all
# Street :  CORONADO AV  Intersection :  18TH ST
# No street_from match
# Street :  EL CAJON BL  Intersection :  ALICE ST
# no match at all
# Street :  EL CAJON BL  Intersection :  ALICE ST
# No street_from match
# Street :  PARK BL  Intersection :  PARK BL  3900
# no match at all
# Street :  PARK BL  Intersection :  PARK BL  3900
# No street_from match
# Street :  GENESEE AV  Intersection :  I-52
# no match at all
# Street :  GENESEE AV  Intersection :  I-52
# No street_from match
# Street :  POINT LOMA AV  Intersection :  CATALINA BL
# no match at all
# Street :  POINT LOMA AV  Intersection :  CATALINA BL
# No street_from match
# Street :  PROSPECT PL  Intersection :  PROSPECT ST
# no match at all
# Street :  PROSPECT PL  Intersection :  PROSPECT ST
# No street_from match
# Street :  HARBOR DR  Intersection :  LANNING RD
# no match at all
# Street :  HARBOR DR  Intersection :  LANNING RD
# No street_from match
# Street :  MARKET ST  Intersection :  I-805
# no match at all
# Street :  MARKET ST  Intersection :  I-805
# No street_from match
# Street :  RANCHO BERNARDO RD  Intersection :  04S RANCH PKWY
# no match at all
# Street :  RANCHO BERNARDO RD  Intersection :  04S RANCH PKWY
# No street_from match
# Street :  HIGHLAND VALLEY RD  Intersection :  HIGHLAND VALLEY RD 14100
# no match at all
# Street :  HIGHLAND VALLEY RD  Intersection :  HIGHLAND VALLEY RD 14100
# No street_from match
# Street :  FLORIDA DR  Intersection :  BOB WILSON DR
# no match at all
# Street :  FLORIDA DR  Intersection :  BOB WILSON DR
# No street_from match
# Street :  HOME AV  Intersection :  I-805
# no match at all
# Street :  HOME AV  Intersection :  I-805
# No street_from match
# Street :  SORRENTO VALLEY BL  Intersection :  CAMINO SANTA FE
# no match at all
# Street :  SORRENTO VALLEY BL  Intersection :  CAMINO SANTA FE
# No street_from match
# Street :  EL CAJON BL  Intersection :  EL CAJON BL 6700
# no match at all
# Street :  EL CAJON BL  Intersection :  EL CAJON BL 6700
# No street_from match
# Street :  CORONADO AV  Intersection :  HOLLISTER
# no match at all
# Street :  CORONADO AV  Intersection :  HOLLISTER
# No street_from match
# Street :  GRAMERCY DR  Intersection :  RUFFIN RD
# no match at all
# Street :  GRAMERCY DR  Intersection :  RUFFIN RD
# No street_from match
# Street :  SUNSET CLIFFS BL  Intersection :  I-8
# no match at all
# Street :  SUNSET CLIFFS BL  Intersection :  I-8
# No street_from match
# Street :  GENESEE AV  Intersection :  I-5
# no match at all
# Street :  GENESEE AV  Intersection :  I-5
# No street_from match
# Street :  CARMEL VIEW RD  Intersection :  RUETTE ALLIANTE
# no match at all
# Street :  CARMEL VIEW RD  Intersection :  RUETTE ALLIANTE
# No street_from match
# Street :  SPORTS ARENA BL  Intersection :  SPORTS ARENA BL 4200
# no match at all
# Street :  SPORTS ARENA BL  Intersection :  SPORTS ARENA BL 4200
# No street_from match
# Street :  HOME AV  Intersection :  I-805
# no match at all
# Street :  HOME AV  Intersection :  I-805
# No street_from match
# Street :  MIRAMAR RD  Intersection :  I-805
# no match at all
# Street :  MIRAMAR RD  Intersection :  I-805
# No street_from match
# Street :  LINDA VISTA RD  Intersection :  KORINK AV
# no match at all
# Street :  LINDA VISTA RD  Intersection :  KORINK AV
# No street_from match
# Street :  HOME AV  Intersection :  I-805
# no match at all
# Street :  HOME AV  Intersection :  I-805
# No street_from match
# Street :  CLAIREMONT MESA BL  Intersection :  MERCHANTS WY
# no match at all
# Street :  CLAIREMONT MESA BL  Intersection :  MERCHANTS WY
# No street_from match
# Street :  EL CAJON BL  Intersection :  CHOCTAW DR
# no match at all
# Street :  EL CAJON BL  Intersection :  CHOCTAW DR
# No street_from match
# Street :  OREGON ST  Intersection :  OREGON ST 4300
# no match at all
# Street :  OREGON ST  Intersection :  OREGON ST 4300
# No street_from match
# Street :  EL CAJON BL  Intersection :  EL CAJON BL 6695
# no match at all
# Street :  EL CAJON BL  Intersection :  EL CAJON BL 6695
# No street_from match
# Street :  29TH ST  Intersection :  WEBSTER AV
# no match at all
# Street :  29TH ST  Intersection :  WEBSTER AV
# No street_from match
# Street :  CARMEL VALLEY RD  Intersection :  I-5
# no match at all
# Street :  CARMEL VALLEY RD  Intersection :  I-5
# No street_from match
# Street :  CORONADO AV  Intersection :  27TH ST
# no match at all
# Street :  CORONADO AV  Intersection :  27TH ST
# No street_from match
# Street :  WEST MISSION BAY DR  Intersection :  GLEASON RD
# no match at all
# Street :  WEST MISSION BAY DR  Intersection :  GLEASON RD
# No street_from match
# Street :  EL CAJON BL  Intersection :  ARAGON DR
# no match at all
# Street :  EL CAJON BL  Intersection :  ARAGON DR
# No street_from match
# Street :  FAIRMOUNT AV  Intersection :  I-8
# no match at all
# Street :  FAIRMOUNT AV  Intersection :  I-8
# No street_from match
# Street :  ADAMS AV  Intersection :  MANSFIELD ST
# no match at all
# Street :  ADAMS AV  Intersection :  MANSFIELD ST
# No street_from match
# Street :  CABLE ST  Intersection :  WEST POINT LOMA BL
# no match at all
# Street :  CABLE ST  Intersection :  WEST POINT LOMA BL
# No street_from match
# Street :  MIRA MESA BL  Intersection :  SEQUENCE DR
# no match at all
# Street :  MIRA MESA BL  Intersection :  SEQUENCE DR
# No street_from match
# Street :  LA JOLLA BL  Intersection :  SEA RIDGE DR
# no match at all
# Street :  LA JOLLA BL  Intersection :  SEA RIDGE DR
# No street_from match
# Street :  WEST BERNARDO DR  Intersection :  MATINAL DR
# no match at all
# Street :  WEST BERNARDO DR  Intersection :  MATINAL DR
# No street_from match
# Street :  ROLL DR  Intersection :  ROLL DR 2310
# no match at all
# Street :  ROLL DR  Intersection :  ROLL DR 2310
# No street_from match
# Street :  POMERADO RD  Intersection :  I-15
# no match at all
# Street :  POMERADO RD  Intersection :  I-15
# No street_from match
# Street :  27TH ST  Intersection :  ELM AV
# no match at all
# Street :  27TH ST  Intersection :  ELM AV
# No street_from match
# Street :  EL CAJON BL  Intersection :  EL CAJON BL 5900
# no match at all
# Street :  EL CAJON BL  Intersection :  EL CAJON BL 5900
# No street_from match
# Street :  WILLOW CREEK RD  Intersection :  WILLOW CREEK RD 10000
# no match at all
# Street :  WILLOW CREEK RD  Intersection :  WILLOW CREEK RD 10000
# No street_from match
# Street :  SHOAL CREEK DR  Intersection :  WINDCREST LN
# no match at all
# Street :  SHOAL CREEK DR  Intersection :  WINDCREST LN
# No street_from match
# Street :  WEST MISSION BAY DR  Intersection :  GLEASON RD
# no match at all
# Street :  WEST MISSION BAY DR  Intersection :  GLEASON RD
# No street_from match
# Street :  MIRA MESA BL  Intersection :  VISTA SORRENTO PKWY
# no match at all
# Street :  MIRA MESA BL  Intersection :  VISTA SORRENTO PKWY
# No street_from match
# Street :  LOPELIA MEADOWS PL  Intersection :  SILVER BRUSH CREEK
# no match at all
# Street :  LOPELIA MEADOWS PL  Intersection :  SILVER BRUSH CREEK
# No street_from match
# Street :  COLLEGE AV  Intersection :  ZURA WY
# no match at all
# Street :  COLLEGE AV  Intersection :  ZURA WY
# No street_from match
# Street :  NORTH HARBOR DR  Intersection :  WINSHIP LN
# no match at all
# Street :  NORTH HARBOR DR  Intersection :  WINSHIP LN
# No street_from match
# Street :  CORONADO AV  Intersection :  16TH ST
# no match at all
# Street :  CORONADO AV  Intersection :  16TH ST
# No street_from match
# Street :  MAIN ST  Intersection :  INDUSTRIAL AV
# no match at all
# Street :  MAIN ST  Intersection :  INDUSTRIAL AV
# No street_from match
# Street :  FRIARS RD  Intersection :  I-15
# no match at all
# Street :  FRIARS RD  Intersection :  I-15
# No street_from match
# Street :  HEALTH CENTER DR  Intersection :  MESA COLLEGE DR
# no match at all
# Street :  HEALTH CENTER DR  Intersection :  MESA COLLEGE DR
# No street_from match
# Street :  CORONADO AV  Intersection :  16TH ST
# no match at all
# Street :  CORONADO AV  Intersection :  16TH ST
# No street_from match
# Street :  EUCLID AV  Intersection :  MARILOU RD
# no match at all
# Street :  EUCLID AV  Intersection :  MARILOU RD
# No street_from match
# Street :  FRIARS RD  Intersection :  I-15
# no match at all
# Street :  FRIARS RD  Intersection :  I-15
# No street_from match
# Street :  MISSION GORGE RD  Intersection :  ELECTRICAL BOX F6151
# no match at all
# Street :  MISSION GORGE RD  Intersection :  ELECTRICAL BOX F6151
# No street_from match
# Street :  SEA WORLD DR  Intersection :  SOUTH SHORES PARK DR
# no match at all
# Street :  SEA WORLD DR  Intersection :  SOUTH SHORES PARK DR
# No street_from match
# Street :  INGRAHAM ST  Intersection :  PEREZ COVE
# no match at all
# Street :  INGRAHAM ST  Intersection :  PEREZ COVE
# No street_from match
# Street :  TIERRASANTA BL  Intersection :  TIERRASANTA BL 11255
# no match at all
# Street :  TIERRASANTA BL  Intersection :  TIERRASANTA BL 11255
# No street_from match
# Street :  CLAIREMONT DR  Intersection :  I-5
# no match at all
# Street :  CLAIREMONT DR  Intersection :  I-5
# No street_from match
# Street :  DEL MAR HEIGHTS RD  Intersection :  I-5
# no match at all
# Street :  DEL MAR HEIGHTS RD  Intersection :  I-5
# No street_from match
# Street :  MISSION BL  Intersection :  MISSION BL 3200
# no match at all
# Street :  MISSION BL  Intersection :  MISSION BL 3200
# No street_from match
# Street :  SORRENTO VALLEY BL  Intersection :  CAMINO SANTA FE
# no match at all
# Street :  SORRENTO VALLEY BL  Intersection :  CAMINO SANTA FE
# No street_from match
# Street :  WINONA AV  Intersection :  WINONA AV 4300
# no match at all
# Street :  WINONA AV  Intersection :  WINONA AV 4300
# No street_from match
# Street :  40TH ST  Intersection :  40TH ST 3300
# no match at all
# Street :  40TH ST  Intersection :  40TH ST 3300
# No street_from match
# Street :  COLLEGE AV  Intersection :  I-94
# no match at all
# Street :  COLLEGE AV  Intersection :  I-94
# No street_from match
# Street :  SAN JOSE PL  Intersection :  SAN JOSE PL 800
# no match at all
# Street :  SAN JOSE PL  Intersection :  SAN JOSE PL 800
# No street_from match
# Street :  GARNET AV  Intersection :  GARNET AV 1200
# no match at all
# Street :  GARNET AV  Intersection :  GARNET AV 1200
# No street_from match
# Street :  MIRAMAR RD  Intersection :  I-805
# no match at all
# Street :  MIRAMAR RD  Intersection :  I-805
# No street_from match
# Street :  37TH ST  Intersection :  FLORENCE ST
# no match at all
# Street :  37TH ST  Intersection :  FLORENCE ST
# No street_from match
# Street :  OTAY MESA RD  Intersection :  GAILES BL
# no match at all
# Street :  OTAY MESA RD  Intersection :  GAILES BL
# No street_from match
# Street :  MAST BL  Intersection :  WEST HILLS PKWY
# no match at all
# ...
# Street :  SANTO RD  Intersection :  SANTO RD 5700
# no match at all
# Street :  SANTO RD  Intersection :  SANTO RD 5700
# No street_from match
# Street :  AERO DR  Intersection :  J J MONTGOMERY
# no match at all
# Street :  AERO DR  Intersection :  J J MONTGOMERY
# No street_from match
# Street :  LA MEDIA RD  Intersection :  LA MEDIA
# no match at all
# Street :  LA MEDIA RD  Intersection :  LA MEDIA
# No street_from match
# Street :  MIDWAY DR  Intersection :  MIDWAY DR 2700
# no match at all
# Street :  MIDWAY DR  Intersection :  MIDWAY DR 2700
# No street_from match
# Street :  ALVARADO RD  Intersection :  LAKE MURRAY
# no match at all
# Street :  ALVARADO RD  Intersection :  LAKE MURRAY
# No street_from match
# Street :  VIA DE LA VALLE  Intersection :  SANTA FE DOWNS SQ
# no match at all
# Street :  VIA DE LA VALLE  Intersection :  SANTA FE DOWNS SQ
# No street_from match
# Street :  BARNETT AV  Intersection :  ENTERPRISE ST
# no match at all
# Street :  BARNETT AV  Intersection :  ENTERPRISE ST
# No street_from match
# Street :  ACUNA ST  Intersection :  RENEX PL
# no match at all
# Street :  ACUNA ST  Intersection :  RENEX PL
# No street_from match
# Street :  EL CAJON BL  Intersection :  EL CAJON BL 3008
# no match at all
# Street :  EL CAJON BL  Intersection :  EL CAJON BL 3008
# No street_from match
# Street :  UNIVERSITY AV  Intersection :  UNIVERSITY SQUARE
# no match at all
# Street :  UNIVERSITY AV  Intersection :  UNIVERSITY SQUARE
# No street_from match
# Street :  FRIARS RD  Intersection :  I-15
# no match at all
# Street :  FRIARS RD  Intersection :  I-15
# No street_from match
# Street :  CORONADO AV  Intersection :  27TH ST
# no match at all
# Street :  CORONADO AV  Intersection :  27TH ST
# No street_from match
# Street :  UNIVERSITY AV  Intersection :  UNIVERSITY SQUARE
# no match at all
# Street :  UNIVERSITY AV  Intersection :  UNIVERSITY SQUARE
# No street_from match
# Street :  WOODROW AV  Intersection :  CALVOCADO
# no match at all
# Street :  WOODROW AV  Intersection :  CALVOCADO
# No street_from match
# Street :  COLLEGE AV  Intersection :  I-18
# no match at all
# Street :  COLLEGE AV  Intersection :  I-18
# No street_from match
# Street :  24TH ST  Intersection :  POLE # P733111J
# no match at all
# Street :  24TH ST  Intersection :  POLE # P733111J
# No street_from match
# Street :  MIRALANI DR  Intersection :  MIRALANI DR 8300
# no match at all
# Street :  MIRALANI DR  Intersection :  MIRALANI DR 8300
# No street_from match
# Street :  GENESEE AV  Intersection :  I-163
# no match at all
# Street :  GENESEE AV  Intersection :  I-163
# No street_from match
# Street :  NOBEL DR  Intersection :  UNIVERSITY CENTER LN
# no match at all
# Street :  NOBEL DR  Intersection :  UNIVERSITY CENTER LN
# No street_from match
# Street :  LARKDALE AV  Intersection :  BIRMINGHAM WY
# no match at all
# Street :  LARKDALE AV  Intersection :  BIRMINGHAM WY
# No street_from match
# Street :  NORTH HARBOR DR  Intersection :  BROADWAY
# no match at all
# Street :  NORTH HARBOR DR  Intersection :  BROADWAY
# No street_from match
# Street :  ENCINA DR  Intersection :  GWEN ST
# no match at all
# Street :  ENCINA DR  Intersection :  GWEN ST
# No street_from match
# Street :  54TH ST  Intersection :  62ND ST
# no match at all
# Street :  54TH ST  Intersection :  62ND ST
# No street_from match
# Street :  FERN ST  Intersection :  HAWTHORN ST
# no match at all
# Street :  FERN ST  Intersection :  HAWTHORN ST
# No street_from match
# Street :  IMPERIAL AV  Intersection :  STEVENS WY
# no match at all
# Street :  IMPERIAL AV  Intersection :  STEVENS WY
# No street_from match
# Street :  BERNARDO CENTER DR  Intersection :  IBERIA PL
# no match at all
# Street :  BERNARDO CENTER DR  Intersection :  IBERIA PL
# No street_from match
# Street :  CORONADO AV  Intersection :  OUTER RD
# no match at all
# Street :  CORONADO AV  Intersection :  OUTER RD
# No street_from match
# Street :  MIRAMAR WY  Intersection :  LIGHT POLE NUMBER 13298
# no match at all
# Street :  MIRAMAR WY  Intersection :  LIGHT POLE NUMBER 13298
# No street_from match
# Street :  KETTNER BL  Intersection :  KETTNER BL 3500
# no match at all
# Street :  KETTNER BL  Intersection :  KETTNER BL 3500
# No street_from match
# Street :  GILMAN DR  Intersection :  I-5
# no match at all
# Street :  GILMAN DR  Intersection :  I-5
# No street_from match
# Street :  BALBOA AV  Intersection :  BALBOA AVE 9200
# no match at all
# Street :  BALBOA AV  Intersection :  BALBOA AVE 9200
# No street_from match
# Street :  HAWTHORN ST  Intersection :  HAWTHORN ST 500
# no match at all
# Street :  HAWTHORN ST  Intersection :  HAWTHORN ST 500
# No street_from match
# Street :  KEARNY VILLA RD  Intersection :  I-163
# no match at all
# Street :  KEARNY VILLA RD  Intersection :  I-163
# No street_from match
# Street :  TRUXTUN RD  Intersection :  ROSECRANS ST
# no match at all
# Street :  TRUXTUN RD  Intersection :  ROSECRANS ST
# No street_from match
# Street :  CLAIREMONT MESA BL  Intersection :  I-163
# no match at all
# Street :  CLAIREMONT MESA BL  Intersection :  I-163
# No street_from match
# Street :  DAMON AV  Intersection :  MISSION BAY
# no match at all
# Street :  DAMON AV  Intersection :  MISSION BAY
# No street_from match
# Street :  CORONADO AV  Intersection :  OUTER RD
# no match at all
# Street :  CORONADO AV  Intersection :  OUTER RD
# No street_from match
# Street :  IMPERIAL AV  Intersection :  IMPERIAL AV 5300
# no match at all
# Street :  IMPERIAL AV  Intersection :  IMPERIAL AV 5300
# No street_from match
# Street :  EL CAJON BL  Intersection :  EL CAJON BL 6521
# no match at all
# Street :  EL CAJON BL  Intersection :  EL CAJON BL 6521
# No street_from match
# Street :  JEWELL ST  Intersection :  JEWELL ST 4100
# no match at all
# Street :  JEWELL ST  Intersection :  JEWELL ST 4100
# No street_from match
# Street :  SUNSET CLIFFS BL  Intersection :  I-8
# no match at all
# Street :  SUNSET CLIFFS BL  Intersection :  I-8
# No street_from match
# Street :  FEDERAL BL  Intersection :  FEDERAL BL 6300
# no match at all
# Street :  FEDERAL BL  Intersection :  FEDERAL BL 6300
# No street_from match
# Street :  KEARNY VILLA RD  Intersection :  WAXIE WY
# no match at all
# Street :  KEARNY VILLA RD  Intersection :  WAXIE WY
# No street_from match
# Street :  HARBOR DR  Intersection :  SALIDA LOOP
# no match at all
# Street :  HARBOR DR  Intersection :  SALIDA LOOP
# No street_from match
# Street :  CARROLL CANYON RD  Intersection :  CARROLL CANYON RD 9800
# no match at all
# Street :  CARROLL CANYON RD  Intersection :  CARROLL CANYON RD 9800
# No street_from match
# Street :  MIRAMAR RD  Intersection :  ANDERSON AV
# no match at all
# Street :  MIRAMAR RD  Intersection :  ANDERSON AV
# No street_from match
# Street :  SAMPSON ST  Intersection :  BELT ST
# no match at all
# Street :  SAMPSON ST  Intersection :  BELT ST
# No street_from match
# Street :  AIRWAY RD  Intersection :  AIRWAY RD 8468
# no match at all
# Street :  AIRWAY RD  Intersection :  AIRWAY RD 8468
# No street_from match
# Street :  LA JOLLA BL  Intersection :  SEARIDGE DR
# no match at all
# Street :  LA JOLLA BL  Intersection :  SEARIDGE DR
# No street_from match
# Street :  ILLINOIS ST  Intersection :  ILLINOIS ST 4300
# no match at all
# Street :  ILLINOIS ST  Intersection :  ILLINOIS ST 4300
# No street_from match
# Street :  ADAMS AV  Intersection :  BANCROFT ST
# no match at all
# Street :  ADAMS AV  Intersection :  BANCROFT ST
# No street_from match
# Street :  MONTEZUMA RD  Intersection :  AI-ST
# no match at all
# Street :  MONTEZUMA RD  Intersection :  AI-ST
# No street_from match
# Street :  TORREY PINES RD  Intersection :  NATIONAL UNIVERSITY SYSTEM DRWY
# no match at all
# Street :  TORREY PINES RD  Intersection :  NATIONAL UNIVERSITY SYSTEM DRWY
# No street_from match
# Street :  MAIN ST  Intersection :  MAIN ST 2000
# no match at all
# Street :  MAIN ST  Intersection :  MAIN ST 2000
# No street_from match
# Street :  IDLEWILD WY  Intersection :  IDLEWILD WY 3000
# no match at all
# Street :  IDLEWILD WY  Intersection :  IDLEWILD WY 3000
# No street_from match
# Street :  FRIARS RD  Intersection :  I-163
# no match at all
# Street :  FRIARS RD  Intersection :  I-163
# No street_from match
# Street :  EL CAJON BL  Intersection :  COLLEGE AV
# no match at all
# Street :  EL CAJON BL  Intersection :  COLLEGE AV
# No street_from match
# Street :  RANCHO BERNARDO RD  Intersection :  CAMINITO CAMPANA
# no match at all
# Street :  RANCHO BERNARDO RD  Intersection :  CAMINITO CAMPANA
# No street_from match
# Street :  HURLBUT ST  Intersection :  AFTON RD
# no match at all
# Street :  HURLBUT ST  Intersection :  AFTON RD
# No street_from match
# Street :  LANDIS ST  Intersection :  LANDIS ST 3100
# no match at all
# Street :  LANDIS ST  Intersection :  LANDIS ST 3100
# No street_from match
# Street :  CORONADO AV  Intersection :  GREEN BAY ST
# no match at all
# Street :  CORONADO AV  Intersection :  GREEN BAY ST
# No street_from match
# Street :  HOLLISTER ST  Intersection :  HOLLISTER ST 1700
# no match at all
# Street :  HOLLISTER ST  Intersection :  HOLLISTER ST 1700
# No street_from match
# Street :  MAST BL  Intersection :  I-52
# no match at all
# Street :  MAST BL  Intersection :  I-52
# No street_from match
# Street :  W UNIVERSITY AV  Intersection :  COLLEGE AV
# no match at all
# Street :  W UNIVERSITY AV  Intersection :  COLLEGE AV
# No street_from match
# Street :  30TH ST  Intersection :  30TH ST 3345
# no match at all
# Street :  30TH ST  Intersection :  30TH ST 3345
# No street_from match
# Street :  MIRA MESA BL  Intersection :  TARGET DRWY
# no match at all
# Street :  MIRA MESA BL  Intersection :  TARGET DRWY
# No street_from match
# Street :  VIA ENCANTADORAS  Intersection :  DAIRY MAI-RD
# no match at all
# Street :  VIA ENCANTADORAS  Intersection :  DAIRY MAI-RD
# No street_from match
# Street :  FEDERAL BL  Intersection :  FEDERAL BL 6100
# no match at all
# Street :  FEDERAL BL  Intersection :  FEDERAL BL 6100
# No street_from match
# Street :  COLLURA ST  Intersection :  KRENNING ST
# no match at all
# Street :  COLLURA ST  Intersection :  KRENNING ST
# No street_from match
# Street :  PARK BL  Intersection :  I-5
# no match at all
# Street :  PARK BL  Intersection :  I-5
# No street_from match
# Street :  MIRA MESA BL  Intersection :  SEQUENCE DR
# no match at all
# Street :  MIRA MESA BL  Intersection :  SEQUENCE DR
# No street_from match
# Street :  CARROLL CANYON RD  Intersection :  I-15
# no match at all
# Street :  CARROLL CANYON RD  Intersection :  I-15
# No street_from match
# Street :  MONTEZUMA RD  Intersection :  AI-ST
# no match at all
# Street :  MONTEZUMA RD  Intersection :  AI-ST
# No street_from match
# Street :  GRAMERCY DR  Intersection :  RUFFIN RD
# no match at all
# Street :  GRAMERCY DR  Intersection :  RUFFIN RD
# No street_from match
# Street :  NORTH HARBOR DR  Intersection :  CELL PHONE LOT ACCESS
# no match at all
# Street :  NORTH HARBOR DR  Intersection :  CELL PHONE LOT ACCESS
# No street_from match
# Street :  NORTH HARBOR DR  Intersection :  HARBOR ISLAND DR 3300
# no match at all
# Street :  NORTH HARBOR DR  Intersection :  HARBOR ISLAND DR 3300
# No street_from match
# Street :  HARBOR DR  Intersection :  TERMINAL ACCESS RD
# no match at all
# Street :  HARBOR DR  Intersection :  TERMINAL ACCESS RD
# No street_from match
# Street :  SANTO RD  Intersection :  SHIELDS ST
# no match at all
# Street :  SANTO RD  Intersection :  SHIELDS ST
# No street_from match
# Street :  CERVANTES AV  Intersection :  PARADISE ST
# no match at all
# Street :  CERVANTES AV  Intersection :  PARADISE ST
# No street match
# Street :  RIVERWALK AT THEATRE WY  Intersection :  THEATER WY
# No street_from match
# Street :  NOBEL DR  Intersection :  TOWNE CENTRE DR
# no match at all
# Street :  NOBEL DR  Intersection :  TOWNE CENTRE DR
# No street_from match
# Street :  INGRAHAM ST  Intersection :  VACATION RD
# no match at all
# Street :  INGRAHAM ST  Intersection :  VACATION RD
# No street_from match
# Street :  NAVAJO RD  Intersection :  CAMINITO PERICO
# no match at all
# Street :  NAVAJO RD  Intersection :  CAMINITO PERICO
# No street_from match
# Street :  HARBOR DR  Intersection :  HARBOR DR 2800
# no match at all
# Street :  HARBOR DR  Intersection :  HARBOR DR 2800
# No street_from match
# Street :  LA JOLLA VILLAGE DR  Intersection :  I-805
# no match at all
# Street :  LA JOLLA VILLAGE DR  Intersection :  I-805
# No street_from match
# Street :  WEST MISSION BAY DR  Intersection :  GLEASON RD
# no match at all
# Street :  WEST MISSION BAY DR  Intersection :  GLEASON RD
# No street_from match
# Street :  NATIONAL AV  Intersection :  NATIONAL AV 3200
# no match at all
# Street :  NATIONAL AV  Intersection :  NATIONAL AV 3200
# No street_from match
# Street :  AERO DR  Intersection :  SANDROCK AV
# no match at all
# Street :  AERO DR  Intersection :  SANDROCK AV
# No street_from match
# Street :  PACIFIC HY  Intersection :  ENTERPRISE
# no match at all
# Street :  PACIFIC HY  Intersection :  ENTERPRISE
# No street_from match
# Street :  TITUS ST  Intersection :  TITUS ST 1845
# no match at all
# Street :  TITUS ST  Intersection :  TITUS ST 1845
# No street match
# Street :  ST-67, SOUTHBOUND  Intersection :  SLAUGHTERHOUSE CANYON ROAD
# No street match
# Street :  SR 52 E/B  Intersection :  SANTO ROAD
# No street match
# Street :  SR 52 E/B  Intersection :  GENESEE AVE
# No street match
# Street :  ST-56 W/B  Intersection :  CARMEL VALLEY ROAD
# No street match
# Street :  ACCESS ROAD US CUSTOMS TO CHP OTAY MESA  Intersection :  ENRICO FERMI DRIVE
# No street match
# Street :  SR163 SB  Intersection :  I-8 O/C
# No street match
# Street :  SR 52 E/B  Intersection :  CONVOY ST O/C
# No street match
# Street :  ST-56 (W/B)  Intersection :  CARMEL VALLEY ROAD
# No street match
# Street :  ST-56 (E/B)  Intersection :  CARMEL COUNTRY ROAD
# No street match
# Street :  INTERSTAE 5 (N/B)  Intersection :  VIA DE LA VALLE
# No street match
# Street :  SR 15 S/B  Intersection :  I-94
# No street match
# Street :  SR 15 S/B  Intersection :  LANDIS ST PED O/C
# No street match
# Street :  AERO DRIVE E/B (9700 BLOCK)  Intersection :  RUFFIN ROAD
# No street match
# Street :  SR 52 E/B  Intersection :  MAST BLVD
# No street match
# Street :  W. UPAS STREET EASTBOUND (1500 BLOCK)  Intersection :  COLUMBIA STREET
# No street match
# Street :  SR163 SB  Intersection :  MESA COLLEGE DR
# No street match
# Street :  ST-163  Intersection :  GENESEE AVENUE
# No street match
# Street :  ST-163  Intersection :  GENESEE AVENUE
# No street match
# Street :  I 805 S/B  Intersection :  NOBEL DR O/C
# No street match
# Street :  CORONADO BAY BRIDGE (SR-75) W/B  Intersection :  I-5
# No street match
# Street :  I -15 NORTH TO CAMINO DEL NORTE  Intersection :  CAMINO DEL NORTE
# No street match
# Street :  SR 52 E/B  Intersection :  MAST BLVD
# No street match
# Street :  SR94 W/B  Intersection :  25TH ST.
# No street match
# Street :  I 805 S/B  Intersection :  BALBOA AVE
# No street match
# Street :  SR 94 W/B  Intersection :  KELTON ROAD
# No street match
# Street :  S.R. 75 E/B    Intersection :  I-5 SOUTHBOUND
# No street match
# Street :  S.R. 75 EASTBOUND (CORONADO BAY BRIDGE)  Intersection :  I-5 SOUTHBOUND
# No street match
# Street :  SR 15 N/B  Intersection :  OCEAN VIEW BLVD
# No street match
# Street :  SR 15 S/B  Intersection :  UNIVERSITY AVE
# No street match
# Street :  SWEETWATER RD. E/B  Intersection :  E/OF BONITA RD.
# No street match
# Street :  1-8 E/B   Intersection :  I-5
# No street match
# Street :  NORTHBOUND I-5 (LOCAL BYPASS)  Intersection :  SR-56 OVERCROSSING
# No street match
# Street :  ST-94 WESTBOUND  Intersection :  EUCLID AVENUE O/C
# No street match
# Street :  I8 EB  Intersection :  MORENA BL
# No street match
# Street :  I -15 S/B  Intersection :  CLAIREMONT MESA BLVD
# No street match
# Street :  SR 94 W/B  Intersection :  KELTON AVE
# No street match
# Street :  SR 52 E/B  Intersection :  MAST BLVD
# No street match
# Street :   I-805 S/B  Intersection :  SR-15 U/C
# No street match
# Street :  163 S/B  Intersection :  ROBINSON AVE.
# No street match
# Street :  I805 NB TO I8 TRANSITION ROAD  Intersection :  ADAMS AVE. O/C
# No street match
# Street :  N/B I-805 TO E/B I-8  Intersection :  I-8
# No street match
# Street :  SR 52 E/B  Intersection :  MAST BLVD
# No street match
# Street :  04TH AVE (900 BLOCK)  Intersection :  E ST
# No street match
# Street :  ST-94 W/B  Intersection :  28TH STREET
# No street match
# Street :  ST-163 (S/B)  Intersection :  GENESEE AVENUE
# No street match
# Street :  ST-15 NORTHBOUND  Intersection :  ADAMS AVENUE
# No street match
# Street :  ST-15 N/B  Intersection :  OCEAN VIEW BOULEVARD
# No street match
# Street :  ST-163 SOUTHBOUND  Intersection :  I-8

# %%
DF= DF.reset_index(drop=True)
#DF
#print(street_len,intersection_len)
#DF2= DF.oci_desc.cumsum()
plt.figure()
#test = count()
DF.oci_desc.value_counts().plot(kind='bar') #far from good model but just to have an idea
plt.show()

# %%
street_name= "15"
intersection = ""
Close_Match_Street = (difflib.get_close_matches(street_name, (DF_OCI['street']),n=1))

DF_JOIN =DF_OCI.loc[(DF_OCI['street'].str.contains(street_name))]

OTHER = DF_JOIN.loc[(DF_JOIN['street_from'].str.contains(intersection))|(DF_OCI['street_to'].str.contains(intersection))]
DF_JOIN

# %%
DF_JOIN = DF_OCI.loc[(DF_OCI['street']== "02ND AV")] 

MVA_DF.loc[(MVA_DF['PRIMARY_RD']== "2ND AV")]

# %%
DF_OCI.street = DF_OCI.street.map(lambda x: difflib.get_close_matches(x, MVA_DF.PRIMARY_RD))

  if len(DF_JOIN) == 1 :
        test = test.append(DF_JOIN)
    elif len(DF_JOIN)> 1 :
        if (DF_JOIN['oci_desc'])[0] == (DF_JOIN['oci_desc'])[1]:
            test = test.append(DF_JOIN.loc[[1]])

            #Check location in OCI where street name matches and where the intersection is either in street to or street from
    elif DF_JOIN.empty : 
        STREET_DF = DF_OCI.loc[DF_OCI['street']==(street_name)]
        A = (difflib.get_close_matches(intersection, (STREET_DF['street_from']),n=1))
        if A== []: 
            #print(A)
            a = a+1 #If it did not find a location
            print("Street : ",street_name," Intersection : ",intersection)
        else :
            DF_JOIN = STREET_DF.loc[STREET_DF.street_from == A[0]]
            test = test.append(DF_JOIN)
            if DF_JOIN.empty : 
                print('NOT SURE TO UNDERSTAND')
         
            

        
       # difflib.get_close_matches(x, df1.index)[0]
            

print(a)
test

# %%
A = difflib.get_close_matches("JUNIPER ST", ["W JUNIPER ST"],1)
A
